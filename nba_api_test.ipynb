# %%
career_dict['resultSets'][0].keys()
# Out:
# dict_keys(['name', 'headers', 'rowSet'])

# %%
cols = career_dict['resultSets'][0]['headers']
print(cols)
# Out:
# ['SEASON_ID', 'Player_ID', 'Game_ID', 'GAME_DATE', 'MATCHUP', 'WL', 'MIN', 'FGM', 'FGA', 'FG_PCT', 'FG3M', 'FG3A', 'FG3_PCT', 'FTM', 'FTA', 'FT_PCT', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS', 'PLUS_MINUS', 'VIDEO_AVAILABLE']

# %%
from nba_api.stats.endpoints import playergamelog

# Nikola Jokić
career = playergamelog.PlayerGameLog(player_id='1627759', season='2024-25')

career_dict = career.get_dict()

career.get_dict()
# Out:
# {'resource': 'playergamelog',
#  'parameters': {'PlayerID': 1627759,
#   'LeagueID': None,
#   'Season': '2024-25',
#   'SeasonType': 'Regular Season',
#   'DateFrom': None,
#   'DateTo': None},
#  'resultSets': [{'name': 'PlayerGameLog',
#    'headers': ['SEASON_ID',
#     'Player_ID',
#     'Game_ID',
#     'GAME_DATE',
#     'MATCHUP',
#     'WL',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS',
#     'PLUS_MINUS',
#     'VIDEO_AVAILABLE'],
#    'rowSet': [['22024',
#      1627759,
#      '0022400891',
#      'MAR 05, 2025',
#      'BOS vs. POR',
#      'W',
#      40,
#      7,
#      23,
#      0.304,
#      0,
#      4,
#      0.0,
#      4,
#      6,
#      0.667,
#      3,
#      5,
#      8,
#      8,
#      1,
#      0,
#      3,
#      2,
#      18,
#      15,
#      1],
#     ['22024',
#      1627759,
#      '0022400866',
#      'MAR 02, 2025',
#      'BOS vs. DEN',
#      'W',
#      37,
#      6,
#      15,
#      0.4,
#      2,
#      4,
#      0.5,
#      8,
#      9,
#      0.889,
#      0,
#      5,
#      5,
#      8,
#      2,
#      2,
#      5,
#      2,
#      22,
#      10,
#      1],
#     ['22024',
#      1627759,
#      '0022400852',
#      'FEB 28, 2025',
#      'BOS vs. CLE',
#      'L',
#      34,
#      13,
#      24,
#      0.542,
#      4,
#      6,
#      0.667,
#      7,
#      10,
#      0.7,
#      4,
#      1,
#      5,
#      2,
#      0,
#      0,
#      3,
#      4,
#      37,
#      10,
#      1],
#     ['22024',
#      1627759,
#      '0022400829',
#      'FEB 25, 2025',
#      'BOS @ TOR',
#      'W',
#      33,
#      10,
#      18,
#      0.556,
#      0,
#      5,
#      0.0,
#      4,
#      4,
#      1.0,
#      1,
#      4,
#      5,
#      4,
#      1,
#      0,
#      3,
#      1,
#      24,
#      5,
#      1],
#     ['22024',
#      1627759,
#      '0022400811',
#      'FEB 23, 2025',
#      'BOS vs. NYK',
#      'W',
#      37,
#      10,
#      21,
#      0.476,
#      2,
#      7,
#      0.286,
#      2,
#      2,
#      1.0,
#      1,
#      7,
#      8,
#      2,
#      2,
#      0,
#      2,
#      2,
#      24,
#      14,
#      1],
#     ['22024',
#      1627759,
#      '0022400789',
#      'FEB 20, 2025',
#      'BOS @ PHI',
#      'W',
#      27,
#      7,
#      13,
#      0.538,
#      2,
#      6,
#      0.333,
#      4,
#      4,
#      1.0,
#      3,
#      3,
#      6,
#      6,
#      0,
#      0,
#      3,
#      1,
#      20,
#      6,
#      1],
#     ['22024',
#      1627759,
#      '0022400748',
#      'FEB 08, 2025',
#      'BOS @ NYK',
#      'W',
#      32,
#      5,
#      14,
#      0.357,
#      0,
#      3,
#      0.0,
#      2,
#      2,
#      1.0,
#      1,
#      2,
#      3,
#      5,
#      3,
#      1,
#      4,
#      3,
#      12,
#      9,
#      1],
#     ['22024',
#      1627759,
#      '0022400728',
#      'FEB 06, 2025',
#      'BOS vs. DAL',
#      'L',
#      33,
#      9,
#      16,
#      0.563,
#      3,
#      4,
#      0.75,
#      4,
#      4,
#      1.0,
#      0,
#      5,
#      5,
#      2,
#      1,
#      0,
#      3,
#      1,
#      25,
#      -15,
#      1],
#     ['22024',
#      1627759,
#      '0022400710',
#      'FEB 04, 2025',
#      'BOS @ CLE',
#      'W',
#      28,
#      7,
#      12,
#      0.583,
#      0,
#      0,
#      0.0,
#      2,
#      2,
#      1.0,
#      2,
#      7,
#      9,
#      6,
#      0,
#      0,
#      5,
#      5,
#      16,
#      -9,
#      1],
#     ['22024',
#      1627759,
#      '0022400698',
#      'FEB 02, 2025',
#      'BOS @ PHI',
#      'W',
#      42,
#      9,
#      17,
#      0.529,
#      2,
#      7,
#      0.286,
#      1,
#      2,
#      0.5,
#      3,
#      7,
#      10,
#      6,
#      1,
#      0,
#      2,
#      4,
#      21,
#      17,
#      1],
#     ['22024',
#      1627759,
#      '0022400683',
#      'JAN 31, 2025',
#      'BOS @ NOP',
#      'W',
#      35,
#      11,
#      18,
#      0.611,
#      3,
#      6,
#      0.5,
#      3,
#      4,
#      0.75,
#      1,
#      5,
#      6,
#      4,
#      0,
#      0,
#      1,
#      4,
#      28,
#      2,
#      1],
#     ['22024',
#      1627759,
#      '0022400666',
#      'JAN 29, 2025',
#      'BOS vs. CHI',
#      'W',
#      36,
#      10,
#      18,
#      0.556,
#      1,
#      5,
#      0.2,
#      7,
#      11,
#      0.636,
#      0,
#      6,
#      6,
#      6,
#      1,
#      0,
#      0,
#      3,
#      28,
#      23,
#      1],
#     ['22024',
#      1627759,
#      '0022400650',
#      'JAN 27, 2025',
#      'BOS vs. HOU',
#      'L',
#      38,
#      10,
#      23,
#      0.435,
#      3,
#      9,
#      0.333,
#      5,
#      6,
#      0.833,
#      0,
#      4,
#      4,
#      4,
#      0,
#      1,
#      2,
#      4,
#      28,
#      -12,
#      1],
#     ['22024',
#      1627759,
#      '0022400635',
#      'JAN 25, 2025',
#      'BOS @ DAL',
#      'W',
#      31,
#      10,
#      21,
#      0.476,
#      0,
#      5,
#      0.0,
#      2,
#      6,
#      0.333,
#      1,
#      7,
#      8,
#      6,
#      0,
#      0,
#      0,
#      4,
#      22,
#      10,
#      1],
#     ['22024',
#      1627759,
#      '0022400629',
#      'JAN 23, 2025',
#      'BOS @ LAL',
#      'L',
#      33,
#      7,
#      19,
#      0.368,
#      3,
#      9,
#      0.333,
#      0,
#      3,
#      0.0,
#      2,
#      6,
#      8,
#      3,
#      1,
#      0,
#      0,
#      2,
#      17,
#      -18,
#      1],
#     ['22024',
#      1627759,
#      '0022400620',
#      'JAN 22, 2025',
#      'BOS @ LAC',
#      'W',
#      39,
#      8,
#      15,
#      0.533,
#      2,
#      2,
#      1.0,
#      7,
#      9,
#      0.778,
#      0,
#      2,
#      2,
#      6,
#      3,
#      1,
#      5,
#      4,
#      25,
#      1,
#      1],
#     ['22024',
#      1627759,
#      '0022400604',
#      'JAN 20, 2025',
#      'BOS @ GSW',
#      'W',
#      29,
#      8,
#      14,
#      0.571,
#      1,
#      3,
#      0.333,
#      0,
#      0,
#      0.0,
#      1,
#      3,
#      4,
#      2,
#      0,
#      0,
#      2,
#      2,
#      17,
#      27,
#      1],
#     ['22024',
#      1627759,
#      '0022400587',
#      'JAN 18, 2025',
#      'BOS vs. ATL',
#      'L',
#      43,
#      9,
#      27,
#      0.333,
#      2,
#      9,
#      0.222,
#      4,
#      5,
#      0.8,
#      6,
#      5,
#      11,
#      8,
#      2,
#      0,
#      4,
#      2,
#      24,
#      -9,
#      1],
#     ['22024',
#      1627759,
#      '0022400577',
#      'JAN 17, 2025',
#      'BOS vs. ORL',
#      'W',
#      33,
#      5,
#      12,
#      0.417,
#      1,
#      2,
#      0.5,
#      9,
#      9,
#      1.0,
#      1,
#      5,
#      6,
#      6,
#      3,
#      0,
#      3,
#      3,
#      20,
#      22,
#      1],
#     ['22024',
#      1627759,
#      '0022400562',
#      'JAN 15, 2025',
#      'BOS @ TOR',
#      'L',
#      33,
#      4,
#      16,
#      0.25,
#      1,
#      1,
#      1.0,
#      1,
#      2,
#      0.5,
#      2,
#      5,
#      7,
#      4,
#      1,
#      0,
#      2,
#      3,
#      10,
#      -23,
#      1],
#     ['22024',
#      1627759,
#      '0022400542',
#      'JAN 12, 2025',
#      'BOS vs. NOP',
#      'W',
#      39,
#      6,
#      14,
#      0.429,
#      0,
#      2,
#      0.0,
#      4,
#      4,
#      1.0,
#      2,
#      6,
#      8,
#      7,
#      0,
#      0,
#      4,
#      3,
#      16,
#      0,
#      1],
#     ['22024',
#      1627759,
#      '0022400528',
#      'JAN 10, 2025',
#      'BOS vs. SAC',
#      'L',
#      35,
#      9,
#      19,
#      0.474,
#      1,
#      5,
#      0.2,
#      9,
#      11,
#      0.818,
#      1,
#      0,
#      1,
#      5,
#      1,
#      1,
#      1,
#      2,
#      28,
#      -9,
#      1],
#     ['22024',
#      1627759,
#      '0022400507',
#      'JAN 07, 2025',
#      'BOS @ DEN',
#      'W',
#      38,
#      6,
#      13,
#      0.462,
#      0,
#      1,
#      0.0,
#      2,
#      2,
#      1.0,
#      0,
#      8,
#      8,
#      8,
#      0,
#      0,
#      4,
#      3,
#      14,
#      5,
#      1],
#     ['22024',
#      1627759,
#      '0022400487',
#      'JAN 05, 2025',
#      'BOS @ OKC',
#      'L',
#      40,
#      8,
#      19,
#      0.421,
#      1,
#      6,
#      0.167,
#      4,
#      4,
#      1.0,
#      0,
#      4,
#      4,
#      3,
#      1,
#      1,
#      3,
#      2,
#      21,
#      -7,
#      1],
#     ['22024',
#      1627759,
#      '0022400449',
#      'DEC 31, 2024',
#      'BOS vs. TOR',
#      'W',
#      25,
#      6,
#      13,
#      0.462,
#      0,
#      2,
#      0.0,
#      0,
#      0,
#      0.0,
#      5,
#      4,
#      9,
#      3,
#      1,
#      0,
#      3,
#      1,
#      12,
#      11,
#      1],
#     ['22024',
#      1627759,
#      '0022400437',
#      'DEC 29, 2024',
#      'BOS vs. IND',
#      'L',
#      36,
#      13,
#      21,
#      0.619,
#      2,
#      6,
#      0.333,
#      3,
#      5,
#      0.6,
#      0,
#      4,
#      4,
#      6,
#      1,
#      0,
#      2,
#      3,
#      31,
#      -10,
#      1],
#     ['22024',
#      1627759,
#      '0022400420',
#      'DEC 27, 2024',
#      'BOS vs. IND',
#      'W',
#      37,
#      16,
#      24,
#      0.667,
#      6,
#      11,
#      0.545,
#      6,
#      6,
#      1.0,
#      3,
#      2,
#      5,
#      3,
#      4,
#      0,
#      1,
#      0,
#      44,
#      30,
#      1],
#     ['22024',
#      1627759,
#      '0022400407',
#      'DEC 25, 2024',
#      'BOS vs. PHI',
#      'L',
#      43,
#      10,
#      23,
#      0.435,
#      3,
#      6,
#      0.5,
#      0,
#      3,
#      0.0,
#      1,
#      6,
#      7,
#      4,
#      2,
#      0,
#      5,
#      4,
#      23,
#      -1,
#      1],
#     ['22024',
#      1627759,
#      '0022400393',
#      'DEC 23, 2024',
#      'BOS @ ORL',
#      'L',
#      37,
#      15,
#      29,
#      0.517,
#      1,
#      7,
#      0.143,
#      4,
#      6,
#      0.667,
#      2,
#      7,
#      9,
#      4,
#      3,
#      0,
#      5,
#      4,
#      35,
#      6,
#      1],
#     ['22024',
#      1627759,
#      '0022400381',
#      'DEC 21, 2024',
#      'BOS @ CHI',
#      'W',
#      33,
#      9,
#      20,
#      0.45,
#      0,
#      5,
#      0.0,
#      1,
#      2,
#      0.5,
#      2,
#      3,
#      5,
#      8,
#      1,
#      0,
#      2,
#      0,
#      19,
#      16,
#      1],
#     ['22024',
#      1627759,
#      '0022400363',
#      'DEC 19, 2024',
#      'BOS vs. CHI',
#      'L',
#      36,
#      7,
#      17,
#      0.412,
#      1,
#      8,
#      0.125,
#      4,
#      5,
#      0.8,
#      1,
#      2,
#      3,
#      4,
#      1,
#      0,
#      3,
#      1,
#      19,
#      -19,
#      1],
#     ['22024',
#      1627759,
#      '0022401217',
#      'DEC 15, 2024',
#      'BOS @ WAS',
#      'W',
#      26,
#      4,
#      14,
#      0.286,
#      2,
#      5,
#      0.4,
#      1,
#      4,
#      0.25,
#      0,
#      3,
#      3,
#      4,
#      3,
#      1,
#      3,
#      1,
#      11,
#      13,
#      1],
#     ['22024',
#      1627759,
#      '0022401205',
#      'DEC 12, 2024',
#      'BOS vs. DET',
#      'W',
#      30,
#      6,
#      12,
#      0.5,
#      1,
#      2,
#      0.5,
#      1,
#      1,
#      1.0,
#      1,
#      8,
#      9,
#      6,
#      1,
#      0,
#      4,
#      1,
#      14,
#      30,
#      1],
#     ['22024',
#      1627759,
#      '0022400345',
#      'DEC 07, 2024',
#      'BOS vs. MEM',
#      'L',
#      35,
#      10,
#      14,
#      0.714,
#      2,
#      3,
#      0.667,
#      0,
#      1,
#      0.0,
#      1,
#      2,
#      3,
#      6,
#      1,
#      0,
#      5,
#      3,
#      22,
#      -17,
#      1],
#     ['22024',
#      1627759,
#      '0022400335',
#      'DEC 06, 2024',
#      'BOS vs. MIL',
#      'W',
#      34,
#      10,
#      21,
#      0.476,
#      3,
#      9,
#      0.333,
#      2,
#      2,
#      1.0,
#      1,
#      2,
#      3,
#      3,
#      0,
#      1,
#      1,
#      3,
#      25,
#      5,
#      1],
#     ['22024',
#      1627759,
#      '0022400319',
#      'DEC 04, 2024',
#      'BOS vs. DET',
#      'W',
#      39,
#      10,
#      21,
#      0.476,
#      1,
#      6,
#      0.167,
#      7,
#      11,
#      0.636,
#      1,
#      5,
#      6,
#      9,
#      3,
#      0,
#      4,
#      0,
#      28,
#      16,
#      1],
#     ['22024',
#      1627759,
#      '0022400316',
#      'DEC 02, 2024',
#      'BOS vs. MIA',
#      'W',
#      31,
#      8,
#      21,
#      0.381,
#      4,
#      11,
#      0.364,
#      9,
#      10,
#      0.9,
#      4,
#      3,
#      7,
#      4,
#      1,
#      0,
#      2,
#      2,
#      29,
#      23,
#      1],
#     ['22024',
#      1627759,
#      '0022400047',
#      'NOV 29, 2024',
#      'BOS @ CHI',
#      'W',
#      37,
#      7,
#      21,
#      0.333,
#      4,
#      10,
#      0.4,
#      3,
#      4,
#      0.75,
#      1,
#      1,
#      2,
#      4,
#      0,
#      0,
#      3,
#      2,
#      21,
#      7,
#      1],
#     ['22024',
#      1627759,
#      '0022400281',
#      'NOV 25, 2024',
#      'BOS vs. LAC',
#      'W',
#      31,
#      6,
#      11,
#      0.545,
#      3,
#      7,
#      0.429,
#      2,
#      4,
#      0.5,
#      0,
#      6,
#      6,
#      4,
#      3,
#      1,
#      3,
#      1,
#      17,
#      11,
#      1],
#     ['22024',
#      1627759,
#      '0022400271',
#      'NOV 24, 2024',
#      'BOS vs. MIN',
#      'W',
#      36,
#      10,
#      18,
#      0.556,
#      7,
#      10,
#      0.7,
#      2,
#      2,
#      1.0,
#      1,
#      1,
#      2,
#      4,
#      1,
#      1,
#      1,
#      4,
#      29,
#      -1,
#      1],
#     ['22024',
#      1627759,
#      '0022400028',
#      'NOV 22, 2024',
#      'BOS @ WAS',
#      'W',
#      37,
#      11,
#      27,
#      0.407,
#      3,
#      13,
#      0.231,
#      6,
#      8,
#      0.75,
#      3,
#      8,
#      11,
#      5,
#      0,
#      0,
#      3,
#      3,
#      31,
#      4,
#      1],
#     ['22024',
#      1627759,
#      '0022400021',
#      'NOV 19, 2024',
#      'BOS vs. CLE',
#      'W',
#      37,
#      7,
#      17,
#      0.412,
#      2,
#      7,
#      0.286,
#      1,
#      2,
#      0.5,
#      0,
#      3,
#      3,
#      8,
#      1,
#      0,
#      4,
#      5,
#      17,
#      17,
#      1],
#     ['22024',
#      1627759,
#      '0022400230',
#      'NOV 16, 2024',
#      'BOS vs. TOR',
#      'W',
#      43,
#      8,
#      16,
#      0.5,
#      2,
#      7,
#      0.286,
#      9,
#      10,
#      0.9,
#      2,
#      4,
#      6,
#      7,
#      0,
#      1,
#      3,
#      5,
#      27,
#      2,
#      1],
#     ['22024',
#      1627759,
#      '0022400218',
#      'NOV 13, 2024',
#      'BOS @ BKN',
#      'W',
#      36,
#      8,
#      19,
#      0.421,
#      2,
#      5,
#      0.4,
#      6,
#      9,
#      0.667,
#      2,
#      10,
#      12,
#      4,
#      1,
#      0,
#      0,
#      2,
#      24,
#      27,
#      1],
#     ['22024',
#      1627759,
#      '0022400001',
#      'NOV 12, 2024',
#      'BOS vs. ATL',
#      'L',
#      36,
#      14,
#      22,
#      0.636,
#      3,
#      6,
#      0.5,
#      6,
#      10,
#      0.6,
#      2,
#      3,
#      5,
#      2,
#      1,
#      0,
#      6,
#      3,
#      37,
#      0,
#      1],
#     ['22024',
#      1627759,
#      '0022400202',
#      'NOV 10, 2024',
#      'BOS @ MIL',
#      'W',
#      37,
#      4,
#      13,
#      0.308,
#      1,
#      5,
#      0.2,
#      5,
#      6,
#      0.833,
#      0,
#      5,
#      5,
#      4,
#      0,
#      0,
#      1,
#      3,
#      14,
#      6,
#      1],
#     ['22024',
#      1627759,
#      '0022400132',
#      'NOV 01, 2024',
#      'BOS @ CHA',
#      'W',
#      37,
#      8,
#      19,
#      0.421,
#      0,
#      6,
#      0.0,
#      9,
#      10,
#      0.9,
#      3,
#      3,
#      6,
#      5,
#      1,
#      1,
#      1,
#      3,
#      25,
#      11,
#      1],
#     ['22024',
#      1627759,
#      '0022400119',
#      'OCT 30, 2024',
#      'BOS @ IND',
#      'L',
#      43,
#      11,
#      30,
#      0.367,
#      1,
#      11,
#      0.091,
#      2,
#      4,
#      0.5,
#      0,
#      6,
#      6,
#      5,
#      2,
#      2,
#      3,
#      4,
#      25,
#      -13,
#      1],
#     ['22024',
#      1627759,
#      '0022400104',
#      'OCT 28, 2024',
#      'BOS vs. MIL',
#      'W',
#      38,
#      10,
#      19,
#      0.526,
#      0,
#      4,
#      0.0,
#      10,
#      14,
#      0.714,
#      1,
#      5,
#      6,
#      4,
#      0,
#      0,
#      4,
#      2,
#      30,
#      8,
#      1],
#     ['22024',
#      1627759,
#      '0022400089',
#      'OCT 26, 2024',
#      'BOS @ DET',
#      'W',
#      38,
#      6,
#      24,
#      0.25,
#      3,
#      9,
#      0.333,
#      9,
#      10,
#      0.9,
#      3,
#      7,
#      10,
#      5,
#      1,
#      0,
#      2,
#      2,
#      24,
#      11,
#      1],
#     ['22024',
#      1627759,
#      '0022400073',
#      'OCT 24, 2024',
#      'BOS @ WAS',
#      'W',
#      30,
#      10,
#      20,
#      0.5,
#      3,
#      6,
#      0.5,
#      4,
#      5,
#      0.8,
#      1,
#      7,
#      8,
#      3,
#      4,
#      0,
#      2,
#      1,
#      27,
#      22,
#      1],
#     ['22024',
#      1627759,
#      '0022400061',
#      'OCT 22, 2024',
#      'BOS vs. NYK',
#      'W',
#      30,
#      7,
#      18,
#      0.389,
#      5,
#      9,
#      0.556,
#      4,
#      4,
#      1.0,
#      2,
#      5,
#      7,
#      1,
#      1,
#      0,
#      1,
#      3,
#      23,
#      23,
#      1]]}]}

# %%
from nba_api.stats.endpoints import boxscoreadvancedv2
import pandas as pd

# Nikola Jokić
career = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id='0022400666')

# dictionary
results = career.get_dict()
data = pd.DataFrame(
    data=results['resultSets'][0]['rowSet'],
    columns=results['resultSets'][0]['headers'])
jb = data[data['PLAYER_ID'] == '1627759']

# %%
jb = data[data['PLAYER_ID'] == 1627759]
jb
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION TEAM_CITY  PLAYER_ID  \
# 13  0022400666  1610612738               BOS    Boston    1627759
#
#      PLAYER_NAME NICKNAME START_POSITION COMMENT           MIN  ...  \
# 13  Jaylen Brown   Jaylen              F          35.000000:37  ...
#
#     TM_TOV_PCT  EFG_PCT  TS_PCT  USG_PCT  E_USG_PCT  E_PACE    PACE  \
# 13         0.0    0.583   0.613    0.277       0.28  105.93  105.12
#
#     PACE_PER40  POSS    PIE
# 13        87.6    77  0.142
#
# [1 rows x 32 columns]

# %%
categories = ['E_USG_PCT', 'E_OFF_RATING', 'E_DEF_RATING', 'PACE_PER40', 'TS_PCT', 'AST_PCT']
jb[categories].iloc[0].to_dict()
# Out:
# {'E_USG_PCT': 0.31,
#  'E_OFF_RATING': 139.4,
#  'E_DEF_RATING': 119.8,
#  'PACE_PER40': 79.08,
#  'TS_PCT': 0.351,
#  'AST_PCT': 0.25}

# %%
jb[['E_USG_PCT', 'E_OFF_RATING', 'E_DEF_RATING', 'PACE_PER40', 'TS_PCT', 'AST_PCT']]
# Out:
#     E_USG_PCT  E_OFF_RATING  E_DEF_RATING  PACE_PER40  TS_PCT  AST_PCT
# 18       0.31         139.4         119.8       79.08   0.351     0.25

# %%
from nba_api.stats.endpoints import teamestimatedmetrics
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
# Nikola Jokić
career = teamestimatedmetrics.TeamEstimatedMetrics(season='2024-25')

# %%
results = career.get_dict()
results
# Out:
# {'resource': 'teamestimatedmetrics',
#  'parameters': {'Season': '2024-25',
#   'SeasonType': 'Regular Season',
#   'LeagueID': '00'},
#  'resultSet': {'name': 'TeamEstimatedMetrics',
#   'headers': ['TEAM_NAME',
#    'TEAM_ID',
#    'GP',
#    'W',
#    'L',
#    'W_PCT',
#    'MIN',
#    'E_OFF_RATING',
#    'E_DEF_RATING',
#    'E_NET_RATING',
#    'E_PACE',
#    'E_AST_RATIO',
#    'E_OREB_PCT',
#    'E_DREB_PCT',
#    'E_REB_PCT',
#    'E_TM_TOV_PCT',
#    'GP_RANK',
#    'W_RANK',
#    'L_RANK',
#    'W_PCT_RANK',
#    'MIN_RANK',
#    'E_OFF_RATING_RANK',
#    'E_DEF_RATING_RANK',
#    'E_NET_RATING_RANK',
#    'E_AST_RATIO_RANK',
#    'E_OREB_PCT_RANK',
#    'E_DREB_PCT_RANK',
#    'E_REB_PCT_RANK',
#    'E_TM_TOV_PCT_RANK',
#    'E_PACE_RANK'],
#   'rowSet': [['Memphis Grizzlies',
#     1610612763,
#     62,
#     38,
#     24,
#     0.613,
#     2981.0,
#     114.6,
#     109.4,
#     5.2,
#     106.9,
#     19.3,
#     0.298,
#     0.743,
#     0.524,
#     0.153,
#     6,
#     7,
#     7,
#     7,
#     16,
#     6,
#     9,
#     5,
#     11,
#     2,
#     20,
#     2,
#     26,
#     1],
#    ['Atlanta Hawks',
#     1610612737,
#     62,
#     28,
#     34,
#     0.452,
#     2996.0,
#     109.9,
#     112.3,
#     -2.4,
#     105.8,
#     19.7,
#     0.258,
#     0.76,
#     0.501,
#     0.149,
#     6,
#     20,
#     19,
#     20,
#     9,
#     19,
#     20,
#     21,
#     9,
#     12,
#     8,
#     13,
#     21,
#     2],
#    ['Chicago Bulls',
#     1610612741,
#     62,
#     24,
#     38,
#     0.387,
#     2991.0,
#     110.4,
#     113.7,
#     -3.3,
#     105.3,
#     19.8,
#     0.216,
#     0.761,
#     0.491,
#     0.141,
#     6,
#     23,
#     23,
#     23,
#     12,
#     17,
#     25,
#     22,
#     7,
#     27,
#     7,
#     23,
#     18,
#     3],
#    ['Washington Wizards',
#     1610612764,
#     61,
#     12,
#     49,
#     0.197,
#     2938.0,
#     103.6,
#     115.9,
#     -12.3,
#     104.0,
#     17.8,
#     0.228,
#     0.732,
#     0.478,
#     0.153,
#     20,
#     30,
#     30,
#     30,
#     26,
#     30,
#     29,
#     30,
#     25,
#     25,
#     25,
#     29,
#     25,
#     4],
#    ['Denver Nuggets',
#     1610612743,
#     62,
#     40,
#     22,
#     0.645,
#     2996.0,
#     117.2,
#     111.9,
#     5.3,
#     102.7,
#     21.1,
#     0.269,
#     0.748,
#     0.521,
#     0.139,
#     6,
#     4,
#     6,
#     6,
#     9,
#     2,
#     16,
#     4,
#     1,
#     7,
#     16,
#     3,
#     16,
#     5],
#    ['Cleveland Cavaliers',
#     1610612739,
#     62,
#     52,
#     10,
#     0.839,
#     2981.0,
#     120.4,
#     108.2,
#     12.2,
#     102.6,
#     20.1,
#     0.255,
#     0.755,
#     0.513,
#     0.128,
#     6,
#     1,
#     1,
#     1,
#     16,
#     1,
#     6,
#     2,
#     4,
#     14,
#     12,
#     6,
#     3,
#     6],
#    ['Oklahoma City Thunder',
#     1610612760,
#     62,
#     51,
#     11,
#     0.823,
#     2981.0,
#     116.7,
#     104.0,
#     12.7,
#     102.5,
#     18.9,
#     0.246,
#     0.737,
#     0.495,
#     0.116,
#     6,
#     2,
#     2,
#     2,
#     16,
#     4,
#     1,
#     1,
#     14,
#     19,
#     23,
#     19,
#     1,
#     7],
#    ['Detroit Pistons',
#     1610612765,
#     63,
#     35,
#     28,
#     0.556,
#     3044.0,
#     111.2,
#     109.9,
#     1.3,
#     102.4,
#     18.6,
#     0.262,
#     0.77,
#     0.519,
#     0.15,
#     2,
#     10,
#     11,
#     11,
#     2,
#     14,
#     10,
#     15,
#     17,
#     9,
#     2,
#     4,
#     22,
#     8],
#    ['Utah Jazz',
#     1610612762,
#     62,
#     15,
#     47,
#     0.242,
#     2996.0,
#     108.9,
#     116.7,
#     -7.8,
#     102.3,
#     18.1,
#     0.278,
#     0.749,
#     0.516,
#     0.168,
#     6,
#     28,
#     28,
#     28,
#     9,
#     23,
#     30,
#     28,
#     21,
#     4,
#     15,
#     5,
#     30,
#     9],
#    ['New Orleans Pelicans',
#     1610612740,
#     62,
#     17,
#     45,
#     0.274,
#     2991.0,
#     108.3,
#     115.7,
#     -7.4,
#     102.2,
#     18.0,
#     0.261,
#     0.722,
#     0.483,
#     0.138,
#     6,
#     27,
#     27,
#     27,
#     12,
#     24,
#     28,
#     27,
#     23,
#     10,
#     29,
#     27,
#     13,
#     10],
#    ['Milwaukee Bucks',
#     1610612749,
#     61,
#     36,
#     25,
#     0.59,
#     2933.0,
#     112.4,
#     110.0,
#     2.5,
#     102.1,
#     18.4,
#     0.197,
#     0.765,
#     0.492,
#     0.134,
#     20,
#     9,
#     8,
#     9,
#     27,
#     12,
#     11,
#     9,
#     19,
#     30,
#     6,
#     20,
#     8,
#     11],
#    ['Indiana Pacers',
#     1610612754,
#     60,
#     35,
#     25,
#     0.583,
#     2895.0,
#     113.9,
#     112.0,
#     1.9,
#     102.0,
#     20.5,
#     0.21,
#     0.738,
#     0.479,
#     0.131,
#     28,
#     10,
#     8,
#     10,
#     28,
#     7,
#     17,
#     12,
#     2,
#     29,
#     22,
#     28,
#     6,
#     12],
#    ['San Antonio Spurs',
#     1610612759,
#     60,
#     26,
#     34,
#     0.433,
#     2890.0,
#     110.7,
#     112.5,
#     -1.7,
#     102.0,
#     20.4,
#     0.242,
#     0.73,
#     0.488,
#     0.138,
#     28,
#     22,
#     19,
#     22,
#     29,
#     16,
#     21,
#     19,
#     3,
#     22,
#     26,
#     25,
#     14,
#     12],
#    ['Golden State Warriors',
#     1610612744,
#     62,
#     34,
#     28,
#     0.548,
#     2981.0,
#     111.0,
#     108.9,
#     2.1,
#     101.8,
#     20.0,
#     0.273,
#     0.758,
#     0.508,
#     0.135,
#     6,
#     13,
#     11,
#     12,
#     16,
#     15,
#     8,
#     11,
#     5,
#     5,
#     9,
#     9,
#     9,
#     14],
#    ['Houston Rockets',
#     1610612745,
#     62,
#     37,
#     25,
#     0.597,
#     2991.0,
#     109.6,
#     107.4,
#     2.2,
#     101.8,
#     15.9,
#     0.314,
#     0.757,
#     0.529,
#     0.136,
#     6,
#     8,
#     8,
#     8,
#     12,
#     21,
#     3,
#     10,
#     30,
#     1,
#     11,
#     1,
#     10,
#     14],
#    ['Toronto Raptors',
#     1610612761,
#     62,
#     20,
#     42,
#     0.323,
#     3001.0,
#     107.6,
#     113.2,
#     -5.6,
#     101.7,
#     19.7,
#     0.264,
#     0.741,
#     0.499,
#     0.153,
#     6,
#     26,
#     26,
#     26,
#     6,
#     26,
#     24,
#     25,
#     8,
#     8,
#     21,
#     16,
#     23,
#     16],
#    ['Sacramento Kings',
#     1610612758,
#     61,
#     32,
#     29,
#     0.525,
#     2963.0,
#     113.6,
#     111.9,
#     1.6,
#     101.6,
#     18.9,
#     0.253,
#     0.769,
#     0.512,
#     0.131,
#     20,
#     15,
#     13,
#     15,
#     21,
#     8,
#     15,
#     14,
#     15,
#     15,
#     4,
#     7,
#     5,
#     17],
#    ['Dallas Mavericks',
#     1610612742,
#     63,
#     32,
#     31,
#     0.508,
#     3034.0,
#     112.5,
#     111.7,
#     0.8,
#     101.6,
#     18.2,
#     0.245,
#     0.729,
#     0.491,
#     0.138,
#     2,
#     15,
#     16,
#     16,
#     3,
#     11,
#     14,
#     16,
#     20,
#     21,
#     27,
#     22,
#     12,
#     17],
#    ['Portland Trail Blazers',
#     1610612757,
#     63,
#     28,
#     35,
#     0.444,
#     3034.0,
#     108.2,
#     112.7,
#     -4.5,
#     101.6,
#     17.1,
#     0.281,
#     0.721,
#     0.498,
#     0.156,
#     2,
#     20,
#     22,
#     21,
#     3,
#     25,
#     23,
#     23,
#     28,
#     3,
#     30,
#     18,
#     28,
#     17],
#    ['Charlotte Hornets',
#     1610612766,
#     61,
#     14,
#     47,
#     0.23,
#     2943.0,
#     103.7,
#     112.3,
#     -8.6,
#     100.5,
#     17.1,
#     0.273,
#     0.748,
#     0.503,
#     0.153,
#     20,
#     29,
#     28,
#     29,
#     24,
#     29,
#     19,
#     29,
#     27,
#     6,
#     18,
#     12,
#     24,
#     20],
#    ['Los Angeles Lakers',
#     1610612747,
#     60,
#     39,
#     21,
#     0.65,
#     2885.0,
#     113.2,
#     110.1,
#     3.2,
#     100.3,
#     19.2,
#     0.232,
#     0.75,
#     0.499,
#     0.139,
#     28,
#     6,
#     4,
#     5,
#     30,
#     10,
#     12,
#     8,
#     12,
#     23,
#     14,
#     17,
#     15,
#     21],
#    ['LA Clippers',
#     1610612746,
#     62,
#     33,
#     29,
#     0.532,
#     2991.0,
#     109.8,
#     108.2,
#     1.7,
#     100.3,
#     18.0,
#     0.247,
#     0.769,
#     0.509,
#     0.154,
#     6,
#     14,
#     13,
#     14,
#     12,
#     20,
#     5,
#     13,
#     24,
#     18,
#     3,
#     8,
#     27,
#     21],
#    ['Minnesota Timberwolves',
#     1610612750,
#     64,
#     35,
#     29,
#     0.547,
#     3087.0,
#     112.1,
#     108.4,
#     3.7,
#     100.0,
#     18.5,
#     0.253,
#     0.744,
#     0.501,
#     0.145,
#     1,
#     10,
#     13,
#     13,
#     1,
#     13,
#     7,
#     6,
#     18,
#     16,
#     19,
#     14,
#     19,
#     23],
#    ['Phoenix Suns',
#     1610612756,
#     62,
#     29,
#     33,
#     0.468,
#     3001.0,
#     113.3,
#     114.9,
#     -1.6,
#     99.9,
#     19.9,
#     0.216,
#     0.735,
#     0.486,
#     0.14,
#     6,
#     17,
#     18,
#     18,
#     6,
#     9,
#     27,
#     18,
#     6,
#     28,
#     24,
#     26,
#     17,
#     24],
#    ['New York Knicks',
#     1610612752,
#     61,
#     40,
#     21,
#     0.656,
#     2953.0,
#     116.2,
#     112.5,
#     3.7,
#     99.8,
#     19.5,
#     0.258,
#     0.748,
#     0.507,
#     0.13,
#     20,
#     4,
#     4,
#     4,
#     22,
#     5,
#     22,
#     6,
#     10,
#     11,
#     17,
#     10,
#     4,
#     25],
#    ['Boston Celtics',
#     1610612738,
#     62,
#     44,
#     18,
#     0.71,
#     3001.0,
#     117.0,
#     108.1,
#     8.9,
#     99.3,
#     18.7,
#     0.246,
#     0.765,
#     0.505,
#     0.12,
#     6,
#     3,
#     3,
#     3,
#     6,
#     3,
#     4,
#     3,
#     16,
#     20,
#     5,
#     11,
#     2,
#     26],
#    ['Philadelphia 76ers',
#     1610612755,
#     61,
#     21,
#     40,
#     0.344,
#     2948.0,
#     109.3,
#     113.8,
#     -4.5,
#     99.2,
#     17.1,
#     0.23,
#     0.727,
#     0.467,
#     0.134,
#     20,
#     24,
#     24,
#     24,
#     23,
#     22,
#     26,
#     23,
#     26,
#     24,
#     28,
#     30,
#     7,
#     27],
#    ['Brooklyn Nets',
#     1610612751,
#     61,
#     21,
#     40,
#     0.344,
#     2943.0,
#     105.6,
#     112.3,
#     -6.7,
#     98.9,
#     18.1,
#     0.252,
#     0.751,
#     0.49,
#     0.156,
#     20,
#     24,
#     24,
#     24,
#     24,
#     27,
#     18,
#     26,
#     22,
#     17,
#     13,
#     24,
#     29,
#     28],
#    ['Orlando Magic',
#     1610612753,
#     63,
#     29,
#     34,
#     0.46,
#     3034.0,
#     104.9,
#     107.0,
#     -2.0,
#     98.8,
#     17.0,
#     0.255,
#     0.777,
#     0.5,
#     0.147,
#     2,
#     17,
#     19,
#     19,
#     3,
#     28,
#     2,
#     20,
#     29,
#     13,
#     1,
#     15,
#     20,
#     29],
#    ['Miami Heat',
#     1610612748,
#     61,
#     29,
#     32,
#     0.475,
#     2973.0,
#     110.0,
#     110.7,
#     -0.6,
#     98.5,
#     19.2,
#     0.219,
#     0.757,
#     0.492,
#     0.137,
#     20,
#     17,
#     17,
#     17,
#     20,
#     18,
#     13,
#     17,
#     13,
#     26,
#     10,
#     21,
#     11,
#     30]]}}

# %%
results = career.get_dict()
data = pd.DataFrame(
    data=results['resultSets'][0]['rowSet'],
    columns=results['resultSets'][0]['headers'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[68], line 3
#       1 results = career.get_dict()
#       2 data = pd.DataFrame(
# ----> 3     data=results['resultSets'][0]['rowSet'],
#       4     columns=results['resultSets'][0]['headers'])
#
# KeyError: 'resultSets'

# %%
data
# Out:
#        TEAM_ID               TEAM_NAME  GP   W   L  W_PCT     MIN   FGM   FGA  \
# 0   1610612737           Atlanta Hawks  62  28  34  0.452  2996.0  2651  5701
# 1   1610612738          Boston Celtics  62  44  18  0.710  3001.0  2580  5594
# 2   1610612751           Brooklyn Nets  61  21  40  0.344  2943.0  2282  5222
# 3   1610612766       Charlotte Hornets  61  14  47  0.230  2943.0  2328  5484
# 4   1610612741           Chicago Bulls  62  24  38  0.387  2991.0  2646  5717
# 5   1610612739     Cleveland Cavaliers  62  52  10  0.839  2981.0  2789  5620
# 6   1610612742        Dallas Mavericks  63  32  31  0.508  3034.0  2643  5574
# 7   1610612743          Denver Nuggets  62  40  22  0.645  2996.0  2831  5585
# 8   1610612765         Detroit Pistons  63  35  28  0.556  3044.0  2685  5645
# 9   1610612744   Golden State Warriors  62  34  28  0.548  2981.0  2549  5694
# 10  1610612745         Houston Rockets  62  37  25  0.597  2991.0  2584  5789
# 11  1610612754          Indiana Pacers  60  35  25  0.583  2895.0  2609  5306
# 12  1610612746             LA Clippers  62  33  29  0.532  2991.0  2528  5364
# 13  1610612747      Los Angeles Lakers  60  39  21  0.650  2885.0  2467  5119
# 14  1610612763       Memphis Grizzlies  62  38  24  0.613  2981.0  2796  5791
# 15  1610612748              Miami Heat  61  29  32  0.475  2973.0  2421  5285
# 16  1610612749         Milwaukee Bucks  61  36  25  0.590  2933.0  2560  5319
# 17  1610612750  Minnesota Timberwolves  64  35  29  0.547  3087.0  2567  5582
# 18  1610612740    New Orleans Pelicans  62  17  45  0.274  2991.0  2539  5631
# 19  1610612752         New York Knicks  61  40  21  0.656  2953.0  2680  5450
# 20  1610612760   Oklahoma City Thunder  62  51  11  0.823  2981.0  2756  5759
# 21  1610612753           Orlando Magic  63  29  34  0.460  3034.0  2376  5398
# 22  1610612755      Philadelphia 76ers  61  21  40  0.344  2948.0  2397  5273
# 23  1610612756            Phoenix Suns  62  29  33  0.468  3001.0  2540  5323
# 24  1610612757  Portland Trail Blazers  63  28  35  0.444  3034.0  2554  5616
# 25  1610612758        Sacramento Kings  61  32  29  0.525  2963.0  2650  5552
# 26  1610612759       San Antonio Spurs  60  26  34  0.433  2890.0  2494  5395
# 27  1610612761         Toronto Raptors  62  20  42  0.323  3001.0  2572  5532
# 28  1610612762               Utah Jazz  62  15  47  0.242  2996.0  2507  5462
# 29  1610612764      Washington Wizards  61  12  49  0.197  2938.0  2407  5477
#
#     FG_PCT  FG3M  FG3A  FG3_PCT   FTM   FTA  FT_PCT  OREB  DREB   REB   AST  \
# 0    0.465   814  2310    0.352  1134  1480   0.766   735  2038  2773  1822
# 1    0.461  1107  2982    0.371   984  1234   0.797   679  2110  2789  1595
# 2    0.437   805  2350    0.343  1033  1295   0.798   674  1834  2508  1509
# 3    0.425   809  2401    0.337   950  1223   0.777   781  2013  2794  1450
# 4    0.463   979  2673    0.366   950  1182   0.804   615  2191  2806  1791
# 5    0.496  1005  2555    0.393  1052  1335   0.788   674  2141  2815  1784
# 6    0.474   821  2231    0.368  1110  1437   0.772   674  2086  2760  1595
# 7    0.507   744  1958    0.380  1097  1414   0.776   699  2153  2852  1928
# 8    0.476   815  2262    0.360  1040  1336   0.778   710  2130  2840  1671
# 9    0.448   948  2638    0.359   969  1299   0.746   795  2060  2855  1807
# 10   0.446   754  2195    0.344  1065  1433   0.743   913  2079  2992  1397
# 11   0.492   782  2099    0.373   994  1267   0.785   530  1931  2461  1750
# 12   0.471   753  2105    0.358  1067  1339   0.797   656  2054  2710  1536
# 13   0.482   750  2112    0.355  1104  1403   0.787   576  1981  2557  1584
# 14   0.483   851  2319    0.367  1180  1513   0.780   823  2125  2948  1800
# 15   0.458   848  2348    0.361  1032  1297   0.796   585  2083  2668  1612
# 16   0.481   871  2274    0.383  1020  1361   0.749   519  2183  2702  1545
# 17   0.460   961  2552    0.377  1104  1387   0.796   702  2109  2811  1634
# 18   0.451   758  2188    0.346  1047  1378   0.760   755  1941  2696  1583
# 19   0.492   770  2080    0.370  1030  1282   0.803   655  1959  2614  1669
# 20   0.479   886  2416    0.367  1020  1236   0.825   680  2088  2768  1665
# 21   0.440   683  2226    0.307  1129  1476   0.765   711  1922  2633  1447
# 22   0.455   764  2215    0.345  1096  1394   0.786   616  1778  2394  1402
# 23   0.477   883  2337    0.378  1095  1359   0.806   564  2082  2646  1718
# 24   0.455   792  2281    0.347  1079  1404   0.769   790  1977  2767  1501
# 25   0.477   763  2170    0.352  1061  1311   0.809   677  2062  2739  1639
# 26   0.462   828  2375    0.349   982  1262   0.778   657  2012  2669  1751
# 27   0.465   708  2029    0.349   992  1327   0.748   728  1995  2723  1763
# 28   0.459   866  2436    0.356  1094  1407   0.778   757  2080  2837  1601
# 29   0.439   792  2372    0.334  1003  1284   0.781   640  2034  2674  1543
#
#        TOV  STL  BLK  BLKA    PF   PFD   PTS  PLUS_MINUS  GP_RANK  W_RANK  \
# 0    981.0  618  321   308  1172  1218  7250      -174.0        6      20
# 1    741.0  447  345   237  1012  1130  7251       532.0        6       3
# 2    946.0  484  269   355  1256  1178  6402      -404.0       20      24
# 3    947.0  482  282   333  1166  1135  6415      -482.0       20      29
# 4    920.0  469  293   317  1101  1021  7221      -264.0        6      23
# 5    809.0  508  274   283  1146  1155  7635       715.0        6       1
# 6    882.0  503  367   298  1158  1174  7217        38.0        2      15
# 7    891.0  506  293   320  1087  1171  7503       317.0        6       4
# 8    975.0  511  326   306  1285  1149  7225       101.0        2      10
# 9    851.0  556  311   349  1208  1120  7015       130.0        6      13
# 10   867.0  526  311   375  1208  1222  6987       205.0        6       8
# 11   807.0  512  312   264  1135  1103  6994        88.0       28      10
# 12   964.0  604  277   277  1156  1102  6876       127.0        6      14
# 13   834.0  465  290   248   994  1171  6788       117.0       28       6
# 14  1019.0  548  363   355  1301  1301  7623       367.0        6       7
# 15   839.0  479  230   289   966  1072  6722       -22.0       20      17
# 16   837.0  443  294   245  1110  1142  7011       147.0       20       9
# 17   933.0  520  310   305  1165  1223  7199       218.0        1      10
# 18   875.0  563  336   336  1118  1113  6883      -494.0        6      27
# 19   801.0  477  239   306  1029  1159  7160       271.0       20       4
# 20   736.0  667  349   291  1268  1129  7418       789.0        6       2
# 21   919.0  563  387   283  1299  1308  6564      -105.0        2      17
# 22   816.0  571  246   319  1189  1167  6654      -289.0       20      24
# 23   873.0  448  317   255  1125  1187  7058      -131.0        6      17
# 24  1005.0  506  342   344  1230  1208  6979      -232.0        2      20
# 25   822.0  479  286   277  1159  1138  7124       105.0       20      15
# 26   845.0  488  375   273   988  1073  6798      -115.0       28      22
# 27   972.0  482  276   350  1338  1157  6844      -355.0        6      26
# 28  1078.0  408  287   398  1178  1220  6974      -452.0        6      28
# 29   977.0  464  313   325  1240  1140  6609      -748.0       20      30
#
#     L_RANK  W_PCT_RANK  MIN_RANK  FGM_RANK  FGA_RANK  FG_PCT_RANK  FG3M_RANK  \
# 0       19          20         9         7         5           14         15
# 1        3           3         6        13        11           18          1
# 2       24          24        24        30        29           29         17
# 3       28          29        24        29        17           30         16
# 4       23          23        12         9         4           16          3
# 5        1           1        16         3         9            2          2
# 6       16          16         3        10        14           12         13
# 7        6           6         9         1        12            1         28
# 8       11          11         2         5         7           11         14
# 9       11          12        16        18         6           25          5
# 10       8           8        12        12         2           26         25
# 11       8          10        28        11        26            4         20
# 12      13          14        12        21        23           13         26
# 13       4           5        30        24        30            6         27
# 14       7           7        16         2         1            5         10
# 15      17          17        20        25        27           21         11
# 16       8           9        27        16        25            7          8
# 17      13          13         1        15        13           19          4
# 18      27          27        12        20         8           24         24
# 19       4           4        22         6        20            3         21
# 20       2           2        16         4         3            8          6
# 21      19          19         3        28        21           27         30
# 22      24          24        23        27        28           23         22
# 23      18          18         6        19        24           10          7
# 24      22          21         3        17        10           22         18
# 25      13          15        21         8        15            9         23
# 26      19          22        29        23        22           17         12
# 27      26          26         6        14        16           15         29
# 28      28          28         9        22        19           20          9
# 29      30          30        26        26        18           28         18
#
#     FG3A_RANK  FG3_PCT_RANK  FTM_RANK  FTA_RANK  FT_PCT_RANK  OREB_RANK  \
# 0          15            19         2         2           24          8
# 1           1             7        26        28            7         15
# 2          11            27        18        22            6         17
# 3           8            28        29        29           20          5
# 4           2            12        29        30            4         25
# 5           4             1        15        17           11         17
# 6          19             9         4         4           22         17
# 7          30             3         7         6           21         13
# 8          18            14        17        16           17         11
# 9           3            15        28        20           29          3
# 10         22            26        13         5           30          1
# 11         27             6        24        25           14         29
# 12         26            16        12        15            8         21
# 13         25            18         5         9           12         27
# 14         14            10         1         1           16          2
# 15         12            13        19        21           10         26
# 16         17             2        21        13           27         30
# 17          5             5         5        11            9         12
# 18         23            24        16        12           26          7
# 19         28             8        20        24            5         22
# 20          7            11        21        27            1         14
# 21         20            30         3         3           25         10
# 22         21            25         8        10           13         24
# 23         13             4         9        14            3         28
# 24         16            23        11         8           23          4
# 25         24            20        14        19            2         16
# 26          9            22        27        26           18         20
# 27         29            21        25        18           28          9
# 28          6            17        10         7           19          6
# 29         10            29        23        23           15         23
#
#     DREB_RANK  REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  \
# 0          18        12         2        27         2        10         17
# 1           7        11        18         2        28         6          1
# 2          29        28        25        21        18        27         27
# 3          20        10        27        22        19        23         22
# 4           1         9         5        19        24        18         18
# 5           4         7         6         5        13        26          9
# 6          10        15        18        16        16         3         13
# 7           3         4         1        17        14        18         20
# 8           5         5        11        25        12         9         15
# 9          16         3         3        12         7        14         25
# 10         14         1        30        13         9        14         29
# 11         27        29         9         4        11        13          5
# 12         17        18        24        23         3        24          7
# 13         23        27        20         8        25        20          3
# 14          6         2         4        29         8         4         27
# 15         11        23        16        10        21        30         11
# 16          2        19        22         9        29        17          2
# 17          8         8        15        20        10        16         14
# 18         26        20        21        15         5         8         23
# 19         25        26        12         3        23        29         15
# 20          9        13        13         1         1         5         12
# 21         28        25        28        18         5         1          9
# 22         30        30        29         6         4        28         19
# 23         12        24        10        14        27        11          4
# 24         24        14        26        28        14         7         24
# 25         15        16        14         7        21        22          7
# 26         21        22         8        11        17         2          6
# 27         22        17         7        24        19        25         26
# 28         13         6        17        30        30        21         30
# 29         19        21        23        26        26        12         21
#
#     PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK
# 0        18         6         6               21
# 1         4        22         5                3
# 2        25         9        30               26
# 3        17        21        29               28
# 4         7        30         8               23
# 5        12        16         1                2
# 6        14        10         9               16
# 7         6        11         3                5
# 8        27        17         7               14
# 9        21        24        14               10
# 10       21         4        17                8
# 11       11        26        16               15
# 12       13        27        21               11
# 13        3        11        24               12
# 14       29         2         2                4
# 15        1        29        25               17
# 16        8        18        15                9
# 17       16         3        10                7
# 18        9        25        20               29
# 19        5        14        11                6
# 20       26        23         4                1
# 21       28         1        28               18
# 22       20        13        26               24
# 23       10         8        13               20
# 24       23         7        18               22
# 25       15        20        12               13
# 26        2        28        23               19
# 27       30        15        22               25
# 28       19         5        19               27
# 29       24        19        27               30
