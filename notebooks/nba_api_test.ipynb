# %%
from nba_api.stats.endpoints import playergamelog

# Nikola Jokić
career = playergamelog.PlayerGameLog(player_id='1627759', season='2024-25')

career_dict = career.get_dict()

career.get_dict()
# Out:
# {'resource': 'playergamelog',
#  'parameters': {'PlayerID': 1627759,
#   'LeagueID': None,
#   'Season': '2024-25',
#   'SeasonType': 'Regular Season',
#   'DateFrom': None,
#   'DateTo': None},
#  'resultSets': [{'name': 'PlayerGameLog',
#    'headers': ['SEASON_ID',
#     'Player_ID',
#     'Game_ID',
#     'GAME_DATE',
#     'MATCHUP',
#     'WL',
#     'MIN',
#     'FGM',
#     'FGA',
#     'FG_PCT',
#     'FG3M',
#     'FG3A',
#     'FG3_PCT',
#     'FTM',
#     'FTA',
#     'FT_PCT',
#     'OREB',
#     'DREB',
#     'REB',
#     'AST',
#     'STL',
#     'BLK',
#     'TOV',
#     'PF',
#     'PTS',
#     'PLUS_MINUS',
#     'VIDEO_AVAILABLE'],
#    'rowSet': [['22024',
#      1627759,
#      '0022400891',
#      'MAR 05, 2025',
#      'BOS vs. POR',
#      'W',
#      40,
#      7,
#      23,
#      0.304,
#      0,
#      4,
#      0.0,
#      4,
#      6,
#      0.667,
#      3,
#      5,
#      8,
#      8,
#      1,
#      0,
#      3,
#      2,
#      18,
#      15,
#      1],
#     ['22024',
#      1627759,
#      '0022400866',
#      'MAR 02, 2025',
#      'BOS vs. DEN',
#      'W',
#      37,
#      6,
#      15,
#      0.4,
#      2,
#      4,
#      0.5,
#      8,
#      9,
#      0.889,
#      0,
#      5,
#      5,
#      8,
#      2,
#      2,
#      5,
#      2,
#      22,
#      10,
#      1],
#     ['22024',
#      1627759,
#      '0022400852',
#      'FEB 28, 2025',
#      'BOS vs. CLE',
#      'L',
#      34,
#      13,
#      24,
#      0.542,
#      4,
#      6,
#      0.667,
#      7,
#      10,
#      0.7,
#      4,
#      1,
#      5,
#      2,
#      0,
#      0,
#      3,
#      4,
#      37,
#      10,
#      1],
#     ['22024',
#      1627759,
#      '0022400829',
#      'FEB 25, 2025',
#      'BOS @ TOR',
#      'W',
#      33,
#      10,
#      18,
#      0.556,
#      0,
#      5,
#      0.0,
#      4,
#      4,
#      1.0,
#      1,
#      4,
#      5,
#      4,
#      1,
#      0,
#      3,
#      1,
#      24,
#      5,
#      1],
#     ['22024',
#      1627759,
#      '0022400811',
#      'FEB 23, 2025',
#      'BOS vs. NYK',
#      'W',
#      37,
#      10,
#      21,
#      0.476,
#      2,
#      7,
#      0.286,
#      2,
#      2,
#      1.0,
#      1,
#      7,
#      8,
#      2,
#      2,
#      0,
#      2,
#      2,
#      24,
#      14,
#      1],
#     ['22024',
#      1627759,
#      '0022400789',
#      'FEB 20, 2025',
#      'BOS @ PHI',
#      'W',
#      27,
#      7,
#      13,
#      0.538,
#      2,
#      6,
#      0.333,
#      4,
#      4,
#      1.0,
#      3,
#      3,
#      6,
#      6,
#      0,
#      0,
#      3,
#      1,
#      20,
#      6,
#      1],
#     ['22024',
#      1627759,
#      '0022400748',
#      'FEB 08, 2025',
#      'BOS @ NYK',
#      'W',
#      32,
#      5,
#      14,
#      0.357,
#      0,
#      3,
#      0.0,
#      2,
#      2,
#      1.0,
#      1,
#      2,
#      3,
#      5,
#      3,
#      1,
#      4,
#      3,
#      12,
#      9,
#      1],
#     ['22024',
#      1627759,
#      '0022400728',
#      'FEB 06, 2025',
#      'BOS vs. DAL',
#      'L',
#      33,
#      9,
#      16,
#      0.563,
#      3,
#      4,
#      0.75,
#      4,
#      4,
#      1.0,
#      0,
#      5,
#      5,
#      2,
#      1,
#      0,
#      3,
#      1,
#      25,
#      -15,
#      1],
#     ['22024',
#      1627759,
#      '0022400710',
#      'FEB 04, 2025',
#      'BOS @ CLE',
#      'W',
#      28,
#      7,
#      12,
#      0.583,
#      0,
#      0,
#      0.0,
#      2,
#      2,
#      1.0,
#      2,
#      7,
#      9,
#      6,
#      0,
#      0,
#      5,
#      5,
#      16,
#      -9,
#      1],
#     ['22024',
#      1627759,
#      '0022400698',
#      'FEB 02, 2025',
#      'BOS @ PHI',
#      'W',
#      42,
#      9,
#      17,
#      0.529,
#      2,
#      7,
#      0.286,
#      1,
#      2,
#      0.5,
#      3,
#      7,
#      10,
#      6,
#      1,
#      0,
#      2,
#      4,
#      21,
#      17,
#      1],
#     ['22024',
#      1627759,
#      '0022400683',
#      'JAN 31, 2025',
#      'BOS @ NOP',
#      'W',
#      35,
#      11,
#      18,
#      0.611,
#      3,
#      6,
#      0.5,
#      3,
#      4,
#      0.75,
#      1,
#      5,
#      6,
#      4,
#      0,
#      0,
#      1,
#      4,
#      28,
#      2,
#      1],
#     ['22024',
#      1627759,
#      '0022400666',
#      'JAN 29, 2025',
#      'BOS vs. CHI',
#      'W',
#      36,
#      10,
#      18,
#      0.556,
#      1,
#      5,
#      0.2,
#      7,
#      11,
#      0.636,
#      0,
#      6,
#      6,
#      6,
#      1,
#      0,
#      0,
#      3,
#      28,
#      23,
#      1],
#     ['22024',
#      1627759,
#      '0022400650',
#      'JAN 27, 2025',
#      'BOS vs. HOU',
#      'L',
#      38,
#      10,
#      23,
#      0.435,
#      3,
#      9,
#      0.333,
#      5,
#      6,
#      0.833,
#      0,
#      4,
#      4,
#      4,
#      0,
#      1,
#      2,
#      4,
#      28,
#      -12,
#      1],
#     ['22024',
#      1627759,
#      '0022400635',
#      'JAN 25, 2025',
#      'BOS @ DAL',
#      'W',
#      31,
#      10,
#      21,
#      0.476,
#      0,
#      5,
#      0.0,
#      2,
#      6,
#      0.333,
#      1,
#      7,
#      8,
#      6,
#      0,
#      0,
#      0,
#      4,
#      22,
#      10,
#      1],
#     ['22024',
#      1627759,
#      '0022400629',
#      'JAN 23, 2025',
#      'BOS @ LAL',
#      'L',
#      33,
#      7,
#      19,
#      0.368,
#      3,
#      9,
#      0.333,
#      0,
#      3,
#      0.0,
#      2,
#      6,
#      8,
#      3,
#      1,
#      0,
#      0,
#      2,
#      17,
#      -18,
#      1],
#     ['22024',
#      1627759,
#      '0022400620',
#      'JAN 22, 2025',
#      'BOS @ LAC',
#      'W',
#      39,
#      8,
#      15,
#      0.533,
#      2,
#      2,
#      1.0,
#      7,
#      9,
#      0.778,
#      0,
#      2,
#      2,
#      6,
#      3,
#      1,
#      5,
#      4,
#      25,
#      1,
#      1],
#     ['22024',
#      1627759,
#      '0022400604',
#      'JAN 20, 2025',
#      'BOS @ GSW',
#      'W',
#      29,
#      8,
#      14,
#      0.571,
#      1,
#      3,
#      0.333,
#      0,
#      0,
#      0.0,
#      1,
#      3,
#      4,
#      2,
#      0,
#      0,
#      2,
#      2,
#      17,
#      27,
#      1],
#     ['22024',
#      1627759,
#      '0022400587',
#      'JAN 18, 2025',
#      'BOS vs. ATL',
#      'L',
#      43,
#      9,
#      27,
#      0.333,
#      2,
#      9,
#      0.222,
#      4,
#      5,
#      0.8,
#      6,
#      5,
#      11,
#      8,
#      2,
#      0,
#      4,
#      2,
#      24,
#      -9,
#      1],
#     ['22024',
#      1627759,
#      '0022400577',
#      'JAN 17, 2025',
#      'BOS vs. ORL',
#      'W',
#      33,
#      5,
#      12,
#      0.417,
#      1,
#      2,
#      0.5,
#      9,
#      9,
#      1.0,
#      1,
#      5,
#      6,
#      6,
#      3,
#      0,
#      3,
#      3,
#      20,
#      22,
#      1],
#     ['22024',
#      1627759,
#      '0022400562',
#      'JAN 15, 2025',
#      'BOS @ TOR',
#      'L',
#      33,
#      4,
#      16,
#      0.25,
#      1,
#      1,
#      1.0,
#      1,
#      2,
#      0.5,
#      2,
#      5,
#      7,
#      4,
#      1,
#      0,
#      2,
#      3,
#      10,
#      -23,
#      1],
#     ['22024',
#      1627759,
#      '0022400542',
#      'JAN 12, 2025',
#      'BOS vs. NOP',
#      'W',
#      39,
#      6,
#      14,
#      0.429,
#      0,
#      2,
#      0.0,
#      4,
#      4,
#      1.0,
#      2,
#      6,
#      8,
#      7,
#      0,
#      0,
#      4,
#      3,
#      16,
#      0,
#      1],
#     ['22024',
#      1627759,
#      '0022400528',
#      'JAN 10, 2025',
#      'BOS vs. SAC',
#      'L',
#      35,
#      9,
#      19,
#      0.474,
#      1,
#      5,
#      0.2,
#      9,
#      11,
#      0.818,
#      1,
#      0,
#      1,
#      5,
#      1,
#      1,
#      1,
#      2,
#      28,
#      -9,
#      1],
#     ['22024',
#      1627759,
#      '0022400507',
#      'JAN 07, 2025',
#      'BOS @ DEN',
#      'W',
#      38,
#      6,
#      13,
#      0.462,
#      0,
#      1,
#      0.0,
#      2,
#      2,
#      1.0,
#      0,
#      8,
#      8,
#      8,
#      0,
#      0,
#      4,
#      3,
#      14,
#      5,
#      1],
#     ['22024',
#      1627759,
#      '0022400487',
#      'JAN 05, 2025',
#      'BOS @ OKC',
#      'L',
#      40,
#      8,
#      19,
#      0.421,
#      1,
#      6,
#      0.167,
#      4,
#      4,
#      1.0,
#      0,
#      4,
#      4,
#      3,
#      1,
#      1,
#      3,
#      2,
#      21,
#      -7,
#      1],
#     ['22024',
#      1627759,
#      '0022400449',
#      'DEC 31, 2024',
#      'BOS vs. TOR',
#      'W',
#      25,
#      6,
#      13,
#      0.462,
#      0,
#      2,
#      0.0,
#      0,
#      0,
#      0.0,
#      5,
#      4,
#      9,
#      3,
#      1,
#      0,
#      3,
#      1,
#      12,
#      11,
#      1],
#     ['22024',
#      1627759,
#      '0022400437',
#      'DEC 29, 2024',
#      'BOS vs. IND',
#      'L',
#      36,
#      13,
#      21,
#      0.619,
#      2,
#      6,
#      0.333,
#      3,
#      5,
#      0.6,
#      0,
#      4,
#      4,
#      6,
#      1,
#      0,
#      2,
#      3,
#      31,
#      -10,
#      1],
#     ['22024',
#      1627759,
#      '0022400420',
#      'DEC 27, 2024',
#      'BOS vs. IND',
#      'W',
#      37,
#      16,
#      24,
#      0.667,
#      6,
#      11,
#      0.545,
#      6,
#      6,
#      1.0,
#      3,
#      2,
#      5,
#      3,
#      4,
#      0,
#      1,
#      0,
#      44,
#      30,
#      1],
#     ['22024',
#      1627759,
#      '0022400407',
#      'DEC 25, 2024',
#      'BOS vs. PHI',
#      'L',
#      43,
#      10,
#      23,
#      0.435,
#      3,
#      6,
#      0.5,
#      0,
#      3,
#      0.0,
#      1,
#      6,
#      7,
#      4,
#      2,
#      0,
#      5,
#      4,
#      23,
#      -1,
#      1],
#     ['22024',
#      1627759,
#      '0022400393',
#      'DEC 23, 2024',
#      'BOS @ ORL',
#      'L',
#      37,
#      15,
#      29,
#      0.517,
#      1,
#      7,
#      0.143,
#      4,
#      6,
#      0.667,
#      2,
#      7,
#      9,
#      4,
#      3,
#      0,
#      5,
#      4,
#      35,
#      6,
#      1],
#     ['22024',
#      1627759,
#      '0022400381',
#      'DEC 21, 2024',
#      'BOS @ CHI',
#      'W',
#      33,
#      9,
#      20,
#      0.45,
#      0,
#      5,
#      0.0,
#      1,
#      2,
#      0.5,
#      2,
#      3,
#      5,
#      8,
#      1,
#      0,
#      2,
#      0,
#      19,
#      16,
#      1],
#     ['22024',
#      1627759,
#      '0022400363',
#      'DEC 19, 2024',
#      'BOS vs. CHI',
#      'L',
#      36,
#      7,
#      17,
#      0.412,
#      1,
#      8,
#      0.125,
#      4,
#      5,
#      0.8,
#      1,
#      2,
#      3,
#      4,
#      1,
#      0,
#      3,
#      1,
#      19,
#      -19,
#      1],
#     ['22024',
#      1627759,
#      '0022401217',
#      'DEC 15, 2024',
#      'BOS @ WAS',
#      'W',
#      26,
#      4,
#      14,
#      0.286,
#      2,
#      5,
#      0.4,
#      1,
#      4,
#      0.25,
#      0,
#      3,
#      3,
#      4,
#      3,
#      1,
#      3,
#      1,
#      11,
#      13,
#      1],
#     ['22024',
#      1627759,
#      '0022401205',
#      'DEC 12, 2024',
#      'BOS vs. DET',
#      'W',
#      30,
#      6,
#      12,
#      0.5,
#      1,
#      2,
#      0.5,
#      1,
#      1,
#      1.0,
#      1,
#      8,
#      9,
#      6,
#      1,
#      0,
#      4,
#      1,
#      14,
#      30,
#      1],
#     ['22024',
#      1627759,
#      '0022400345',
#      'DEC 07, 2024',
#      'BOS vs. MEM',
#      'L',
#      35,
#      10,
#      14,
#      0.714,
#      2,
#      3,
#      0.667,
#      0,
#      1,
#      0.0,
#      1,
#      2,
#      3,
#      6,
#      1,
#      0,
#      5,
#      3,
#      22,
#      -17,
#      1],
#     ['22024',
#      1627759,
#      '0022400335',
#      'DEC 06, 2024',
#      'BOS vs. MIL',
#      'W',
#      34,
#      10,
#      21,
#      0.476,
#      3,
#      9,
#      0.333,
#      2,
#      2,
#      1.0,
#      1,
#      2,
#      3,
#      3,
#      0,
#      1,
#      1,
#      3,
#      25,
#      5,
#      1],
#     ['22024',
#      1627759,
#      '0022400319',
#      'DEC 04, 2024',
#      'BOS vs. DET',
#      'W',
#      39,
#      10,
#      21,
#      0.476,
#      1,
#      6,
#      0.167,
#      7,
#      11,
#      0.636,
#      1,
#      5,
#      6,
#      9,
#      3,
#      0,
#      4,
#      0,
#      28,
#      16,
#      1],
#     ['22024',
#      1627759,
#      '0022400316',
#      'DEC 02, 2024',
#      'BOS vs. MIA',
#      'W',
#      31,
#      8,
#      21,
#      0.381,
#      4,
#      11,
#      0.364,
#      9,
#      10,
#      0.9,
#      4,
#      3,
#      7,
#      4,
#      1,
#      0,
#      2,
#      2,
#      29,
#      23,
#      1],
#     ['22024',
#      1627759,
#      '0022400047',
#      'NOV 29, 2024',
#      'BOS @ CHI',
#      'W',
#      37,
#      7,
#      21,
#      0.333,
#      4,
#      10,
#      0.4,
#      3,
#      4,
#      0.75,
#      1,
#      1,
#      2,
#      4,
#      0,
#      0,
#      3,
#      2,
#      21,
#      7,
#      1],
#     ['22024',
#      1627759,
#      '0022400281',
#      'NOV 25, 2024',
#      'BOS vs. LAC',
#      'W',
#      31,
#      6,
#      11,
#      0.545,
#      3,
#      7,
#      0.429,
#      2,
#      4,
#      0.5,
#      0,
#      6,
#      6,
#      4,
#      3,
#      1,
#      3,
#      1,
#      17,
#      11,
#      1],
#     ['22024',
#      1627759,
#      '0022400271',
#      'NOV 24, 2024',
#      'BOS vs. MIN',
#      'W',
#      36,
#      10,
#      18,
#      0.556,
#      7,
#      10,
#      0.7,
#      2,
#      2,
#      1.0,
#      1,
#      1,
#      2,
#      4,
#      1,
#      1,
#      1,
#      4,
#      29,
#      -1,
#      1],
#     ['22024',
#      1627759,
#      '0022400028',
#      'NOV 22, 2024',
#      'BOS @ WAS',
#      'W',
#      37,
#      11,
#      27,
#      0.407,
#      3,
#      13,
#      0.231,
#      6,
#      8,
#      0.75,
#      3,
#      8,
#      11,
#      5,
#      0,
#      0,
#      3,
#      3,
#      31,
#      4,
#      1],
#     ['22024',
#      1627759,
#      '0022400021',
#      'NOV 19, 2024',
#      'BOS vs. CLE',
#      'W',
#      37,
#      7,
#      17,
#      0.412,
#      2,
#      7,
#      0.286,
#      1,
#      2,
#      0.5,
#      0,
#      3,
#      3,
#      8,
#      1,
#      0,
#      4,
#      5,
#      17,
#      17,
#      1],
#     ['22024',
#      1627759,
#      '0022400230',
#      'NOV 16, 2024',
#      'BOS vs. TOR',
#      'W',
#      43,
#      8,
#      16,
#      0.5,
#      2,
#      7,
#      0.286,
#      9,
#      10,
#      0.9,
#      2,
#      4,
#      6,
#      7,
#      0,
#      1,
#      3,
#      5,
#      27,
#      2,
#      1],
#     ['22024',
#      1627759,
#      '0022400218',
#      'NOV 13, 2024',
#      'BOS @ BKN',
#      'W',
#      36,
#      8,
#      19,
#      0.421,
#      2,
#      5,
#      0.4,
#      6,
#      9,
#      0.667,
#      2,
#      10,
#      12,
#      4,
#      1,
#      0,
#      0,
#      2,
#      24,
#      27,
#      1],
#     ['22024',
#      1627759,
#      '0022400001',
#      'NOV 12, 2024',
#      'BOS vs. ATL',
#      'L',
#      36,
#      14,
#      22,
#      0.636,
#      3,
#      6,
#      0.5,
#      6,
#      10,
#      0.6,
#      2,
#      3,
#      5,
#      2,
#      1,
#      0,
#      6,
#      3,
#      37,
#      0,
#      1],
#     ['22024',
#      1627759,
#      '0022400202',
#      'NOV 10, 2024',
#      'BOS @ MIL',
#      'W',
#      37,
#      4,
#      13,
#      0.308,
#      1,
#      5,
#      0.2,
#      5,
#      6,
#      0.833,
#      0,
#      5,
#      5,
#      4,
#      0,
#      0,
#      1,
#      3,
#      14,
#      6,
#      1],
#     ['22024',
#      1627759,
#      '0022400132',
#      'NOV 01, 2024',
#      'BOS @ CHA',
#      'W',
#      37,
#      8,
#      19,
#      0.421,
#      0,
#      6,
#      0.0,
#      9,
#      10,
#      0.9,
#      3,
#      3,
#      6,
#      5,
#      1,
#      1,
#      1,
#      3,
#      25,
#      11,
#      1],
#     ['22024',
#      1627759,
#      '0022400119',
#      'OCT 30, 2024',
#      'BOS @ IND',
#      'L',
#      43,
#      11,
#      30,
#      0.367,
#      1,
#      11,
#      0.091,
#      2,
#      4,
#      0.5,
#      0,
#      6,
#      6,
#      5,
#      2,
#      2,
#      3,
#      4,
#      25,
#      -13,
#      1],
#     ['22024',
#      1627759,
#      '0022400104',
#      'OCT 28, 2024',
#      'BOS vs. MIL',
#      'W',
#      38,
#      10,
#      19,
#      0.526,
#      0,
#      4,
#      0.0,
#      10,
#      14,
#      0.714,
#      1,
#      5,
#      6,
#      4,
#      0,
#      0,
#      4,
#      2,
#      30,
#      8,
#      1],
#     ['22024',
#      1627759,
#      '0022400089',
#      'OCT 26, 2024',
#      'BOS @ DET',
#      'W',
#      38,
#      6,
#      24,
#      0.25,
#      3,
#      9,
#      0.333,
#      9,
#      10,
#      0.9,
#      3,
#      7,
#      10,
#      5,
#      1,
#      0,
#      2,
#      2,
#      24,
#      11,
#      1],
#     ['22024',
#      1627759,
#      '0022400073',
#      'OCT 24, 2024',
#      'BOS @ WAS',
#      'W',
#      30,
#      10,
#      20,
#      0.5,
#      3,
#      6,
#      0.5,
#      4,
#      5,
#      0.8,
#      1,
#      7,
#      8,
#      3,
#      4,
#      0,
#      2,
#      1,
#      27,
#      22,
#      1],
#     ['22024',
#      1627759,
#      '0022400061',
#      'OCT 22, 2024',
#      'BOS vs. NYK',
#      'W',
#      30,
#      7,
#      18,
#      0.389,
#      5,
#      9,
#      0.556,
#      4,
#      4,
#      1.0,
#      2,
#      5,
#      7,
#      1,
#      1,
#      0,
#      1,
#      3,
#      23,
#      23,
#      1]]}]}

# %%
from nba_api.stats.endpoints import boxscoreadvancedv2
import pandas as pd

# Nikola Jokić
career = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id='0022400528')

# dictionary
results = career.get_dict()
data = pd.DataFrame(
    data=results['resultSets'][0]['rowSet'],
    columns=results['resultSets'][0]['headers'])
jb = data[data['PLAYER_ID'] == '1627759']

# %%
jb = data[data['PLAYER_ID'] == 1627759]
jb
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION TEAM_CITY  PLAYER_ID  \
# 14  0022400528  1610612738               BOS    Boston    1627759
#
#      PLAYER_NAME NICKNAME START_POSITION COMMENT           MIN  ...  \
# 14  Jaylen Brown   Jaylen              F          35.000000:06  ...
#
#     TM_TOV_PCT  EFG_PCT  TS_PCT  USG_PCT  E_USG_PCT  E_PACE   PACE  \
# 14         3.3      0.5   0.587    0.321      0.321   101.8  99.15
#
#     PACE_PER40  POSS    PIE
# 14       82.62    72  0.123
#
# [1 rows x 32 columns]

# %%
categories = ['E_USG_PCT', 'E_OFF_RATING', 'E_DEF_RATING', 'PACE_PER40', 'TS_PCT', 'AST_PCT']
jb[categories].iloc[0].to_dict()
# Out:
# {'E_USG_PCT': 0.31,
#  'E_OFF_RATING': 139.4,
#  'E_DEF_RATING': 119.8,
#  'PACE_PER40': 79.08,
#  'TS_PCT': 0.351,
#  'AST_PCT': 0.25}

# %%
jb[['E_USG_PCT', 'E_OFF_RATING', 'E_DEF_RATING', 'PACE_PER40', 'TS_PCT', 'AST_PCT']]
# Out:
#     E_USG_PCT  E_OFF_RATING  E_DEF_RATING  PACE_PER40  TS_PCT  AST_PCT
# 18       0.31         139.4         119.8       79.08   0.351     0.25

# %%
from nba_api.stats.endpoints import teamestimatedmetrics
import pandas as pd
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
# Nikola Jokić
career = teamestimatedmetrics.TeamEstimatedMetrics(season='2024-25')

# %%
results = career.get_data_frames()

# %%
results = career.get_dict()
data = pd.DataFrame(
    data=results['resultSet']['rowSet'],
    columns=results['resultSet']['headers'])

# %%
data2 = data[['TEAM_NAME','TEAM_ID','E_OFF_RATING','E_DEF_RATING', 'E_PACE']]

# %%
data2
# Out:
#                  TEAM_NAME     TEAM_ID  E_OFF_RATING  E_DEF_RATING  E_PACE
# 0        Memphis Grizzlies  1610612763         114.6         109.4   106.9
# 1            Atlanta Hawks  1610612737         110.1         112.4   105.7
# 2            Chicago Bulls  1610612741         110.5         113.7   105.4
# 3       Washington Wizards  1610612764         103.6         115.9   104.0
# 4           Denver Nuggets  1610612743         117.2         111.9   102.7
# 5      Cleveland Cavaliers  1610612739         120.4         108.2   102.6
# 6    Oklahoma City Thunder  1610612760         116.7         104.0   102.5
# 7          Detroit Pistons  1610612765         111.2         109.9   102.4
# 8                Utah Jazz  1610612762         108.9         116.7   102.3
# 9          Milwaukee Bucks  1610612749         112.4         110.0   102.1
# 10    New Orleans Pelicans  1610612740         108.1         115.6   102.1
# 11          Indiana Pacers  1610612754         114.0         112.2   102.0
# 12       San Antonio Spurs  1610612759         110.7         112.5   102.0
# 13   Golden State Warriors  1610612744         111.2         109.1   101.8
# 14         Houston Rockets  1610612745         109.6         107.3   101.8
# 15         Toronto Raptors  1610612761         107.6         113.2   101.7
# 16        Sacramento Kings  1610612758         113.6         111.9   101.6
# 17        Dallas Mavericks  1610612742         112.5         111.7   101.6
# 18  Portland Trail Blazers  1610612757         108.2         112.7   101.6
# 19       Charlotte Hornets  1610612766         103.7         112.3   100.5
# 20             LA Clippers  1610612746         109.8         108.2   100.3
# 21      Los Angeles Lakers  1610612747         113.1         109.9   100.2
# 22  Minnesota Timberwolves  1610612750         112.1         108.4   100.0
# 23            Phoenix Suns  1610612756         113.3         114.9    99.9
# 24         New York Knicks  1610612752         115.9         112.4    99.8
# 25          Boston Celtics  1610612738         117.2         108.0    99.2
# 26      Philadelphia 76ers  1610612755         109.3         114.1    99.1
# 27           Orlando Magic  1610612753         105.1         107.2    98.9
# 28           Brooklyn Nets  1610612751         105.8         112.5    98.9
# 29              Miami Heat  1610612748         110.0         110.7    98.5

# %%
data2[['SEASON_ID']] = '22024'
# Out:
# /var/folders/fm/7zh52wdj2mx7v17vqtcy7ggc0000gn/T/ipykernel_79879/528538719.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data2[['SEASON_ID']] = '22024'

# %%
data2
# Out:
#                  TEAM_NAME     TEAM_ID  E_OFF_RATING  E_DEF_RATING  E_PACE  \
# 0        Memphis Grizzlies  1610612763         114.6         109.4   106.9
# 1            Atlanta Hawks  1610612737         110.1         112.4   105.7
# 2            Chicago Bulls  1610612741         110.5         113.7   105.4
# 3       Washington Wizards  1610612764         103.6         115.9   104.0
# 4           Denver Nuggets  1610612743         117.2         111.9   102.7
# 5      Cleveland Cavaliers  1610612739         120.4         108.2   102.6
# 6    Oklahoma City Thunder  1610612760         116.7         104.0   102.5
# 7          Detroit Pistons  1610612765         111.2         109.9   102.4
# 8                Utah Jazz  1610612762         108.9         116.7   102.3
# 9          Milwaukee Bucks  1610612749         112.4         110.0   102.1
# 10    New Orleans Pelicans  1610612740         108.1         115.6   102.1
# 11          Indiana Pacers  1610612754         114.0         112.2   102.0
# 12       San Antonio Spurs  1610612759         110.7         112.5   102.0
# 13   Golden State Warriors  1610612744         111.2         109.1   101.8
# 14         Houston Rockets  1610612745         109.6         107.3   101.8
# 15         Toronto Raptors  1610612761         107.6         113.2   101.7
# 16        Sacramento Kings  1610612758         113.6         111.9   101.6
# 17        Dallas Mavericks  1610612742         112.5         111.7   101.6
# 18  Portland Trail Blazers  1610612757         108.2         112.7   101.6
# 19       Charlotte Hornets  1610612766         103.7         112.3   100.5
# 20             LA Clippers  1610612746         109.8         108.2   100.3
# 21      Los Angeles Lakers  1610612747         113.1         109.9   100.2
# 22  Minnesota Timberwolves  1610612750         112.1         108.4   100.0
# 23            Phoenix Suns  1610612756         113.3         114.9    99.9
# 24         New York Knicks  1610612752         115.9         112.4    99.8
# 25          Boston Celtics  1610612738         117.2         108.0    99.2
# 26      Philadelphia 76ers  1610612755         109.3         114.1    99.1
# 27           Orlando Magic  1610612753         105.1         107.2    98.9
# 28           Brooklyn Nets  1610612751         105.8         112.5    98.9
# 29              Miami Heat  1610612748         110.0         110.7    98.5
#
#    SEASON_ID
# 0      22024
# 1      22024
# 2      22024
# 3      22024
# 4      22024
# 5      22024
# 6      22024
# 7      22024
# 8      22024
# 9      22024
# 10     22024
# 11     22024
# 12     22024
# 13     22024
# 14     22024
# 15     22024
# 16     22024
# 17     22024
# 18     22024
# 19     22024
# 20     22024
# 21     22024
# 22     22024
# 23     22024
# 24     22024
# 25     22024
# 26     22024
# 27     22024
# 28     22024
# 29     22024

# %%
from nba_api.stats.static import teams
import pandas as pd

# Get list of all NBA teams with IDs
nba_teams = teams.get_teams()
team_df = pd.DataFrame(nba_teams)

# Display team abbreviations & IDs
team_df[['id', 'abbreviation', 'full_name']]
# Out:
#             id abbreviation               full_name
# 0   1610612737          ATL           Atlanta Hawks
# 1   1610612738          BOS          Boston Celtics
# 2   1610612739          CLE     Cleveland Cavaliers
# 3   1610612740          NOP    New Orleans Pelicans
# 4   1610612741          CHI           Chicago Bulls
# 5   1610612742          DAL        Dallas Mavericks
# 6   1610612743          DEN          Denver Nuggets
# 7   1610612744          GSW   Golden State Warriors
# 8   1610612745          HOU         Houston Rockets
# 9   1610612746          LAC    Los Angeles Clippers
# 10  1610612747          LAL      Los Angeles Lakers
# 11  1610612748          MIA              Miami Heat
# 12  1610612749          MIL         Milwaukee Bucks
# 13  1610612750          MIN  Minnesota Timberwolves
# 14  1610612751          BKN           Brooklyn Nets
# 15  1610612752          NYK         New York Knicks
# 16  1610612753          ORL           Orlando Magic
# 17  1610612754          IND          Indiana Pacers
# 18  1610612755          PHI      Philadelphia 76ers
# 19  1610612756          PHX            Phoenix Suns
# 20  1610612757          POR  Portland Trail Blazers
# 21  1610612758          SAC        Sacramento Kings
# 22  1610612759          SAS       San Antonio Spurs
# 23  1610612760          OKC   Oklahoma City Thunder
# 24  1610612761          TOR         Toronto Raptors
# 25  1610612762          UTA               Utah Jazz
# 26  1610612763          MEM       Memphis Grizzlies
# 27  1610612764          WAS      Washington Wizards
# 28  1610612765          DET         Detroit Pistons
# 29  1610612766          CHA       Charlotte Hornets

# %%
import pandas as pd
from nba_api.stats.endpoints import leaguegamefinder
# Fetch all games for the current season
season = "2023-24"  # Modify this as needed
gamefinder = leaguegamefinder.LeagueGameFinder(season_nullable=season)
games_df = gamefinder.get_data_frames()[0]

# # Keep only relevant columns
# games_df = games_df[["GAME_ID", "GAME_DATE", "TEAM_ID", "MATCHUP"]]

# # Split MATCHUP column to get home/away teams
# def extract_teams(row):
#     parts = row["MATCHUP"].split(" ")
#     if "vs." in row["MATCHUP"]:
#         home_team, away_team = parts[0], parts[2]
#     elif "@" in row["MATCHUP"]:
#         away_team, home_team = parts[0], parts[2]
#     return pd.Series({"home_team_abbr": home_team, "away_team_abbr": away_team})

# games_df[["home_team_abbr", "away_team_abbr"]] = games_df.apply(extract_teams, axis=1)

# %%
games_df
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION         TEAM_NAME     GAME_ID  \
# 0        42023  1610612738               BOS    Boston Celtics  0042300405
# 1        42023  1610612742               DAL  Dallas Mavericks  0042300405
# 2        42023  1610612742               DAL  Dallas Mavericks  0042300404
# 3        42023  1610612738               BOS    Boston Celtics  0042300404
# 4        42023  1610612738               BOS    Boston Celtics  0042300403
# ...        ...         ...               ...               ...         ...
# 4378     12023  1610612742               DAL  Dallas Mavericks  0012300001
# 4379     12023         104               PER    Perth Wildcats  2012300002
# 4380     12023  1612709930               GLI   G League Ignite  2012300002
# 4381     12023         104               PER    Perth Wildcats  2012300001
# 4382     12023  1612709930               GLI   G League Ignite  2012300001
#
#        GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 0     2024-06-17  BOS vs. DAL  W  240  106   38   89   0.427    13    39
# 1     2024-06-17    DAL @ BOS  L  240   88   35   78   0.449    11    37
# 2     2024-06-14  DAL vs. BOS  W  240  122   46   91   0.505    15    37
# 3     2024-06-14    BOS @ DAL  L  239   84   29   80   0.363    14    41
# 4     2024-06-12    BOS @ DAL  W  240  106   38   82   0.463    17    46
# ...          ...          ... ..  ...  ...  ...  ...     ...   ...   ...
# 4378  2023-10-05    DAL @ MIN  L  240   99   34   92   0.370    14    46
# 4379  2023-09-08    PER @ GLI  W  238  127   39   77   0.506    15    29
# 4380  2023-09-08  GLI vs. PER  L  240  112   37   90   0.411     9    29
# 4381  2023-09-06    PER @ GLI  L  239  105   36   91   0.396    11    36
# 4382  2023-09-06  GLI vs. PER  W  240  124   48   82   0.585     8    22
#
#       FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0       0.333   17   20   0.850    15    36   51   25    9    2    7  15
# 1       0.297    7   13   0.538     7    28   35   18    4    4   13  20
# 2       0.405   15   22   0.682    13    39   52   21    7    2    8  17
# 3       0.341   12   13   0.923     4    27   31   18    2    5   13  19
# 4       0.370   13   14   0.929     6    30   36   26    4    6    9  19
# ...       ...  ...  ...     ...   ...   ...  ...  ...  ...  ...  ...  ..
# 4378    0.304   17   30   0.567     7    35   42   18   11    8   13  25
# 4379    0.517   34   39   0.872    10    29   39   25   10    8   21  23
# 4380    0.310   29   35   0.829    17    25   42   24   12   10   17  29
# 4381    0.306   22   26   0.846    21    19   40   27   13    8   21  21
# 4382    0.364   20   23   0.870    11    32   43   27   12   10   22  23
#
#       PLUS_MINUS
# 0           18.0
# 1          -18.0
# 2           38.0
# 3          -38.0
# 4            7.0
# ...          ...
# 4378       -12.0
# 4379        15.0
# 4380       -15.0
# 4381       -19.0
# 4382        19.0
#
# [4383 rows x 28 columns]

# %%
BOS_games = games_df.loc[games_df['TEAM_ABBREVIATION'] == 'BOS',['GAME_ID']]
BOS_games.reset_index(inplace=True, drop=True)
BOS_games['GAME_ID']
for g in BOS_games['GAME_ID']:
    print(g)
# Out:
# 0042300405
# 0042300404
# 0042300403
# 0042300402
# 0042300401
# 0042300304
# 0042300303
# 0042300302
# 0042300301
# 0042300205
# 0042300204
# 0042300203
# 0042300202
# 0042300201
# 0042300105
# 0042300104
# 0042300103
# 0042300102
# 0042300101
# 0022301186
# 0022301173
# 0022301167
# 0022301148
# 0022301134
# 0022301118
# 0022301105
# 0022301087
# 0022301074
# 0022301060
# 0022301034
# 0022301023
# 0022301011
# 0022300998
# 0022300984
# 0022300980
# 0022300955
# 0022300943
# 0022300938
# 0022300920
# 0022300906
# 0022300886
# 0022300872
# 0022300859
# 0022300836
# 0022300816
# 0022300797
# 0022300780
# 0022300771
# 0022300759
# 0022300743
# 0022300729
# 0022300706
# 0022300684
# 0022300670
# 0022300659
# 0022300646
# 0022300630
# 0022300611
# 0022300603
# 0022300586
# 0022300571
# 0022300563
# 0022300542
# 0022300528
# 0022300517
# 0022300507
# 0022300493
# 0022300479
# 0022300462
# 0022300448
# 0022300432
# 0022300421
# 0022300403
# 0022300389
# 0022300373
# 0022300362
# 0022300344
# 0022300329
# 0022300319
# 0022300305
# 0022301227
# 0022301202
# 0022300275
# 0022300053
# 0022300246
# 0022300043
# 0022300228
# 0022300217
# 0022300213
# 0022300031
# 0022300194
# 0022300188
# 0022300174
# 0022300010
# 0022300159
# 0022300154
# 0022300136
# 0022300118
# 0022300103
# 0022300080
# 0022300065
# 0012300060
# 0012300051
# 0012300023
# 0012300010
# 0012300006

# %%
df = pd.read_parquet('../data/raw/BOS/BOS_0012300006.parquet')
df[df['actionType'] =='Turnover']
# Out:
#          gameId  actionNumber        clock  period      teamId teamTricode  \
# 7    0012300006            14  PT10M37.00S       1  1610612738         BOS
# 73   0012300006           102  PT04M59.00S       1  1610612738         BOS
# 91   0012300006           131  PT03M04.00S       1  1610612755         PHI
# 109  0012300006           153  PT01M27.00S       1  1610612738         BOS
# 111  0012300006           155  PT01M15.00S       1  1610612755         PHI
# 117  0012300006           164  PT00M41.00S       1  1610612738         BOS
# 130  0012300006           180  PT00M00.20S       1  1610612755         PHI
# 192  0012300006           267  PT06M32.00S       2  1610612755         PHI
# 198  0012300006           274  PT06M05.00S       2  1610612738         BOS
# 224  0012300006           311  PT03M27.00S       2  1610612755         PHI
# 226  0012300006           313  PT03M22.00S       2  1610612738         BOS
# 242  0012300006           333  PT02M16.00S       2  1610612738         BOS
# 287  0012300006           403  PT10M11.00S       3  1610612738         BOS
# 297  0012300006           412  PT09M44.00S       3  1610612738         BOS
# 318  0012300006           439  PT07M48.00S       3  1610612755         PHI
# 333  0012300006           461  PT05M54.00S       3  1610612738         BOS
# 371  0012300006           507  PT03M38.00S       3  1610612755         PHI
# 372  0012300006           520  PT03M26.00S       3  1610612738         BOS
# 373  0012300006           511  PT03M14.00S       3  1610612755         PHI
# 382  0012300006           525  PT02M11.00S       3  1610612755         PHI
# 392  0012300006           542  PT01M46.00S       3  1610612755         PHI
# 399  0012300006           551  PT01M09.00S       3  1610612738         BOS
# 409  0012300006           562  PT00M24.90S       3  1610612738         BOS
# 416  0012300006           573  PT11M47.00S       4  1610612738         BOS
# 433  0012300006           595  PT09M29.00S       4  1610612755         PHI
# 448  0012300006           618  PT07M26.00S       4  1610612738         BOS
# 461  0012300006           634  PT05M26.00S       4  1610612738         BOS
# 471  0012300006           646  PT04M35.00S       4  1610612755         PHI
# 475  0012300006           651  PT04M11.00S       4  1610612755         PHI
# 518  0012300006           698  PT00M15.80S       4  1610612755         PHI
#
#      personId playerName   playerNameI  xLegacy  yLegacy  shotDistance  \
# 7     1628369      Tatum      J. Tatum        0        0             0
# 73    1628401      White      D. White        0        0             0
# 91    1626162  Oubre Jr.  K. Oubre Jr.        0        0             0
# 109   1628436     Kornet     L. Kornet        0        0             0
# 111    202699     Harris     T. Harris        0        0             0
# 117    201950    Holiday    J. Holiday        0        0             0
# 130    200782     Tucker     P. Tucker        0        0             0
# 192    201980      Green      D. Green        0        0             0
# 198   1628401      White      D. White        0        0             0
# 224    202699     Harris     T. Harris        0        0             0
# 226   1627759      Brown      J. Brown        0        0             0
# 242   1627759      Brown      J. Brown        0        0             0
# 287    204001  Porziņģis  K. Porziņģis        0        0             0
# 297   1628401      White      D. White        0        0             0
# 318   1630531   Springer   J. Springer        0        0             0
# 333    204001  Porziņģis  K. Porziņģis        0        0             0
# 371   1628964      Bamba      M. Bamba        0        0             0
# 372    204001  Porziņģis  K. Porziņģis        0        0             0
# 373   1627863  House Jr.  D. House Jr.        0        0             0
# 382   1630561   Duke Jr.   D. Duke Jr.        0        0             0
# 392   1630561   Duke Jr.   D. Duke Jr.        0        0             0
# 399   1628436     Kornet     L. Kornet        0        0             0
# 409   1630202  Pritchard  P. Pritchard        0        0             0
# 416   1630202  Pritchard  P. Pritchard        0        0             0
# 433   1630606      Smart      J. Smart        0        0             0
# 448   1628436     Kornet     L. Kornet        0        0             0
# 461   1630625     Banton     D. Banton        0        0             0
# 471   1630606      Smart      J. Smart        0        0             0
# 475   1630531   Springer   J. Springer        0        0             0
# 518   1631173      Smith      T. Smith        0        0             0
#
#     shotResult  isFieldGoal scoreHome scoreAway  pointsTotal location  \
# 7                         0                                0        h
# 73                        0                                0        h
# 91                        0                                0        v
# 109                       0                                0        h
# 111                       0                                0        v
# 117                       0                                0        h
# 130                       0                                0        v
# 192                       0                                0        v
# 198                       0                                0        h
# 224                       0                                0        v
# 226                       0                                0        h
# 242                       0                                0        h
# 287                       0                                0        h
# 297                       0                                0        h
# 318                       0                                0        v
# 333                       0                                0        h
# 371                       0                                0        v
# 372                       0                                0        h
# 373                       0                                0        v
# 382                       0                                0        v
# 392                       0                                0        v
# 399                       0                                0        h
# 409                       0                                0        h
# 416                       0                                0        h
# 433                       0                                0        v
# 448                       0                                0        h
# 461                       0                                0        h
# 471                       0                                0        v
# 475                       0                                0        v
# 518                       0                                0        v
#
#                                            description actionType  \
# 7                     Tatum Lost Ball Turnover (P1.T1)   Turnover
# 73      White Out of Bounds Lost Ball Turnover (P1.T2)   Turnover
# 91                 Oubre Jr. Bad Pass Turnover (P1.T1)   Turnover
# 109                  Kornet Lost Ball Turnover (P1.T3)   Turnover
# 111  Harris Out of Bounds - Bad Pass Turnover Turno...   Turnover
# 117                 Holiday Traveling Turnover (P1.T4)   Turnover
# 130                   Tucker Bad Pass Turnover (P1.T3)   Turnover
# 192  Green Out of Bounds - Bad Pass Turnover Turnov...   Turnover
# 198                   White Lost Ball Turnover (P2.T5)   Turnover
# 224                  Harris Lost Ball Turnover (P2.T5)   Turnover
# 226                   Brown Lost Ball Turnover (P1.T6)   Turnover
# 242  Brown Out of Bounds - Bad Pass Turnover Turnov...   Turnover
# 287               Porzingis Lost Ball Turnover (P1.T8)   Turnover
# 297              White Offensive Foul Turnover (P3.T9)   Turnover
# 318                Springer Lost Ball Turnover (P1.T6)   Turnover
# 333               Porzingis Bad Pass Turnover (P2.T10)   Turnover
# 371  Bamba Out of Bounds - Bad Pass Turnover Turnov...   Turnover
# 372  Porzingis Offensive Goaltending Turnover (P3.T11)   Turnover
# 373                House Jr. Bad Pass Turnover (P1.T8)   Turnover
# 382                Duke Jr. Lost Ball Turnover (P1.T9)   Turnover
# 392               Duke Jr. Lost Ball Turnover (P2.T10)   Turnover
# 399            Kornet Offensive Foul Turnover (P2.T12)   Turnover
# 409               Pritchard Bad Pass Turnover (P1.T13)   Turnover
# 416               Pritchard Bad Pass Turnover (P2.T14)   Turnover
# 433                  Smart Traveling Turnover (P1.T11)   Turnover
# 448                  Kornet Bad Pass Turnover (P3.T15)   Turnover
# 461                 Banton Lost Ball Turnover (P1.T16)   Turnover
# 471  Smart Out of Bounds - Bad Pass Turnover Turnov...   Turnover
# 475                Springer Bad Pass Turnover (P2.T13)   Turnover
# 518  Smith Out of Bounds - Bad Pass Turnover Turnov...   Turnover
#
#                                subType  videoAvailable  shotValue  actionId
# 7                            Lost Ball               1          0         8
# 73    Out of Bounds Lost Ball Turnover               1          0        74
# 91                            Bad Pass               1          0        92
# 109                          Lost Ball               1          0       110
# 111  Out of Bounds - Bad Pass Turnover               1          0       112
# 117                          Traveling               1          0       118
# 130                           Bad Pass               1          0       131
# 192  Out of Bounds - Bad Pass Turnover               1          0       193
# 198                          Lost Ball               1          0       199
# 224                          Lost Ball               1          0       225
# 226                          Lost Ball               1          0       227
# 242  Out of Bounds - Bad Pass Turnover               1          0       243
# 287                          Lost Ball               1          0       288
# 297            Offensive Foul Turnover               1          0       298
# 318                          Lost Ball               1          0       319
# 333                           Bad Pass               1          0       334
# 371  Out of Bounds - Bad Pass Turnover               1          0       372
# 372              Offensive Goaltending               1          0       373
# 373                           Bad Pass               1          0       374
# 382                          Lost Ball               1          0       383
# 392                          Lost Ball               1          0       393
# 399            Offensive Foul Turnover               1          0       400
# 409                           Bad Pass               1          0       410
# 416                           Bad Pass               1          0       417
# 433                          Traveling               1          0       434
# 448                           Bad Pass               1          0       449
# 461                          Lost Ball               1          0       462
# 471  Out of Bounds - Bad Pass Turnover               1          0       472
# 475                           Bad Pass               1          0       476
# 518  Out of Bounds - Bad Pass Turnover               1          0       519

# %%
# Keep only relevant columns
games_df = games_df[["GAME_ID", "GAME_DATE", "TEAM_ID", "MATCHUP"]]

# Split MATCHUP column to get home/away teams
def extract_teams(row):
    parts = row["MATCHUP"].split(" ")
    if "vs." in row["MATCHUP"]:
        home_team, away_team = parts[0], parts[2]
    elif "@" in row["MATCHUP"]:
        away_team, home_team = parts[0], parts[2]
    return pd.Series({"home_team_abbr": home_team, "away_team_abbr": away_team})

games_df[["home_team_abbr", "away_team_abbr"]] = games_df.apply(extract_teams, axis=1)
# Out:
# /var/folders/fm/7zh52wdj2mx7v17vqtcy7ggc0000gn/T/ipykernel_79879/2533903528.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games_df[["home_team_abbr", "away_team_abbr"]] = games_df.apply(extract_teams, axis=1)
# /var/folders/fm/7zh52wdj2mx7v17vqtcy7ggc0000gn/T/ipykernel_79879/2533903528.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   games_df[["home_team_abbr", "away_team_abbr"]] = games_df.apply(extract_teams, axis=1)

# %%
import pandas as pd
from nba_api.stats.endpoints import leaguegamefinder

# Fetch all games for the current season
season = "2023-24"  # Modify this as needed
gamefinder = leaguegamefinder.LeagueGameFinder(season_nullable=season)
games_df = gamefinder.get_data_frames()[0]

# Keep only relevant columns
games_df = games_df[["GAME_ID", "GAME_DATE", "TEAM_ID", "MATCHUP"]]

# Split MATCHUP column to get home/away teams
def extract_teams(row):
    parts = row["MATCHUP"].split(" ")
    if "vs." in row["MATCHUP"]:
        home_team, away_team = parts[0], parts[2]
    elif "@" in row["MATCHUP"]:
        away_team, home_team = parts[0], parts[2]
    return pd.Series({"home_team_abbr": home_team, "away_team_abbr": away_team})

games_df[["home_team_abbr", "away_team_abbr"]] = games_df.apply(extract_teams, axis=1)

# Merge with team IDs using the Teams table
conn = sqlite3.connect(DB_PATH)
teams_df = pd.read_sql("SELECT * FROM Teams;", conn)

# Create a mapping of abbreviations to team IDs
team_abbrev_to_id = dict(zip(teams_df["abbreviation"], teams_df["team_id"]))

# Map team abbreviations to team IDs
games_df["home_team_id"] = games_df["home_team_abbr"].map(team_abbrev_to_id)
games_df["away_team_id"] = games_df["away_team_abbr"].map(team_abbrev_to_id)

# Add season column
games_df["season"] = season

# Rename columns to match database schema
games_df.rename(columns={"GAME_ID": "game_id", "GAME_DATE": "game_date"}, inplace=True)

# Insert into SQLite
games_df.to_sql("Games", conn, if_exists="replace", index=False)
print("✅ Full season schedule inserted successfully!")

# Display table
import ace_tools as tools
tools.display_dataframe_to_user(name="NBA Full Season Schedule", dataframe=games_df)

conn.close()

# %%
import pandas as pd
pd.set_option('display.max_columns', 100)
from nba_api.stats.endpoints import playerindex

data = playerindex.PlayerIndex(season='2024-25', team_id_nullable='1610612738', league_id='00')
data.get_data_frames()[0]
# Out:
#     PERSON_ID PLAYER_LAST_NAME PLAYER_FIRST_NAME         PLAYER_SLUG  \
# 0     1627759            Brown            Jaylen        jaylen-brown
# 1     1628470            Craig            Torrey        torrey-craig
# 2     1631120          Davison                JD          jd-davison
# 3     1630573           Hauser               Sam          sam-hauser
# 4      201950          Holiday              Jrue        jrue-holiday
# 5      201143          Horford                Al          al-horford
# 6     1628436           Kornet              Luke         luke-kornet
# 7     1641936           Norris             Miles        miles-norris
# 8     1641809         Peterson              Drew       drew-peterson
# 9      204001        Porziņģis          Kristaps  kristaps-porziņģis
# 10    1630202        Pritchard            Payton    payton-pritchard
# 11    1629674            Queta           Neemias       neemias-queta
# 12    1631248       Scheierman            Baylor   baylor-scheierman
# 13    1628369            Tatum            Jayson        jayson-tatum
# 14    1630214          Tillman            Xavier      xavier-tillman
# 15    1641775            Walsh            Jordan        jordan-walsh
# 16    1628401            White           Derrick       derrick-white
#
#    TEAM_SLUG     TEAM_ID TEAM_CITY TEAM_NAME TEAM_ABBREVIATION JERSEY_NUMBER  \
# 0    celtics  1610612738    Boston   Celtics               BOS             7
# 1    celtics  1610612738    Boston   Celtics               BOS            12
# 2    celtics  1610612738    Boston   Celtics               BOS            20
# 3    celtics  1610612738    Boston   Celtics               BOS            30
# 4    celtics  1610612738    Boston   Celtics               BOS             4
# 5    celtics  1610612738    Boston   Celtics               BOS            42
# 6    celtics  1610612738    Boston   Celtics               BOS            40
# 7    celtics  1610612738    Boston   Celtics               BOS             0
# 8    celtics  1610612738    Boston   Celtics               BOS            13
# 9    celtics  1610612738    Boston   Celtics               BOS             8
# 10   celtics  1610612738    Boston   Celtics               BOS            11
# 11   celtics  1610612738    Boston   Celtics               BOS            88
# 12   celtics  1610612738    Boston   Celtics               BOS            55
# 13   celtics  1610612738    Boston   Celtics               BOS             0
# 14   celtics  1610612738    Boston   Celtics               BOS            26
# 15   celtics  1610612738    Boston   Celtics               BOS            27
# 16   celtics  1610612738    Boston   Celtics               BOS             9
#
#    POSITION HEIGHT WEIGHT                   COLLEGE             COUNTRY  \
# 0       G-F    6-6    223                California                 USA
# 1         F    6-5    221    South Carolina Upstate                 USA
# 2         G    6-1    195                   Alabama                 USA
# 3         F    6-7    217                  Virginia                 USA
# 4         G    6-4    205                      UCLA                 USA
# 5       C-F    6-9    240                   Florida  Dominican Republic
# 6       C-F    7-1    250                Vanderbilt                 USA
# 7         F    6-7    220  California-Santa Barbara                 USA
# 8         F    6-9    205       Southern California                 USA
# 9       F-C    7-2    240           Cajasol Sevilla              Latvia
# 10        G    6-1    195                    Oregon                 USA
# 11        C    7-0    248                Utah State            Portugal
# 12        G    6-6    205                 Creighton                 USA
# 13      F-G    6-8    210                      Duke                 USA
# 14        F    6-7    245            Michigan State                 USA
# 15        G    6-6    205                  Arkansas                 USA
# 16        G    6-4    190                  Colorado                 USA
#
#     DRAFT_YEAR  DRAFT_ROUND  DRAFT_NUMBER  ROSTER_STATUS FROM_YEAR TO_YEAR  \
# 0       2016.0          1.0           3.0            1.0      2016    2024
# 1          NaN          NaN           NaN            1.0      2017    2024
# 2       2022.0          2.0          53.0            1.0      2022    2024
# 3          NaN          NaN           NaN            1.0      2021    2024
# 4       2009.0          1.0          17.0            1.0      2009    2024
# 5       2007.0          1.0           3.0            1.0      2007    2024
# 6          NaN          NaN           NaN            1.0      2017    2024
# 7          NaN          NaN           NaN            1.0      2024    2024
# 8          NaN          NaN           NaN            1.0      2023    2024
# 9       2015.0          1.0           4.0            1.0      2015    2024
# 10      2020.0          1.0          26.0            1.0      2020    2024
# 11      2021.0          2.0          39.0            1.0      2021    2024
# 12      2024.0          1.0          30.0            1.0      2024    2024
# 13      2017.0          1.0           3.0            1.0      2017    2024
# 14      2020.0          2.0          35.0            1.0      2020    2024
# 15      2023.0          2.0          38.0            1.0      2023    2024
# 16      2017.0          1.0          29.0            1.0      2017    2024
#
#      PTS  REB  AST STATS_TIMEFRAME
# 0   23.3  6.1  4.8          Season
# 1    5.7  2.5  0.5          Season
# 2    1.3  0.3  0.3          Season
# 3    7.8  3.1  0.9          Season
# 4   10.7  4.3  3.6          Season
# 5    8.3  5.8  1.9          Season
# 6    5.2  5.0  1.6          Season
# 7    0.0  2.0  0.0          Season
# 8    2.3  1.7  0.7          Season
# 9   18.9  6.8  1.9          Season
# 10  14.2  3.8  3.5          Season
# 11   5.1  3.9  0.7          Season
# 12   1.6  1.5  0.7          Season
# 13  27.2  8.9  5.8          Season
# 14   1.0  1.3  0.2          Season
# 15   1.6  1.3  0.4          Season
# 16  16.6  4.3  4.4          Season

# %%
from nba_api.stats.endpoints import playerdashboardbyyearoveryear

data = playerdashboardbyyearoveryear.PlayerDashboardByYearOverYear(player_id='1627759', season='2024-25')
data.get_data_frames()[0]
# Out:
#   GROUP_SET GROUP_VALUE     TEAM_ID TEAM_ABBREVIATION        MAX_GAME_DATE  \
# 0   Overall     2024-25  1610612738               BOS  2025-03-12T00:00:00
#
#    GP   W   L  W_PCT          MIN  FGM   FGA  FG_PCT  FG3M  FG3A  FG3_PCT  \
# 0  55  39  16  0.709  1949.161667  471  1025    0.46   102   323    0.316
#
#    FTM  FTA  FT_PCT  OREB  DREB  REB  AST  TOV  STL  BLK  BLKA   PF  PFD  \
# 0  223  294   0.759    80   254  334  261  148   70   17    65  141  273
#
#     PTS  PLUS_MINUS  NBA_FANTASY_PTS  DD2  TD3  WNBA_FANTASY_PTS  GP_RANK  \
# 0  1267         338           2172.3    5    0            2138.0        1
#
#    W_RANK  L_RANK  W_PCT_RANK  MIN_RANK  FGM_RANK  FGA_RANK  FG_PCT_RANK  \
# 0       1       1           1         1         1         1            1
#
#    FG3M_RANK  FG3A_RANK  FG3_PCT_RANK  FTM_RANK  FTA_RANK  FT_PCT_RANK  \
# 0          1          1             1         1         1            1
#
#    OREB_RANK  DREB_RANK  REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  \
# 0          1          1         1         1         1         1         1
#
#    BLKA_RANK  PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  \
# 0          1        1         1         1                1
#
#    NBA_FANTASY_PTS_RANK  DD2_RANK  TD3_RANK  WNBA_FANTASY_PTS_RANK
# 0                     1         1         1                      1

# %%
df = data.get_data_frames()[0]
min_game = df.loc[0,'MIN'] / df.loc[0,'GP']
pf_game = df.loc[0,'PF'] / df.loc[0,'GP']
pf_game
# Out:
# 2.5636363636363635

# %%
from nba_api.stats.endpoints import teamestimatedmetrics
import pandas as pd
team_stats = teamestimatedmetrics.TeamEstimatedMetrics(season='2024-25')
results = team_stats.get_dict()
data = pd.DataFrame(
    data=results['resultSet']['rowSet'],
    columns=results['resultSet']['headers'])

data[data['TEAM_ID'] == 1610612738]
# Out:
#          TEAM_NAME     TEAM_ID  GP   W   L  W_PCT     MIN  E_OFF_RATING  \
# 26  Boston Celtics  1610612738  66  47  19  0.712  3193.0         117.2
#
#     E_DEF_RATING  E_NET_RATING  E_PACE  E_AST_RATIO  E_OREB_PCT  E_DREB_PCT  \
# 26         108.2           9.0    99.2         18.7       0.249       0.762
#
#     E_REB_PCT  E_TM_TOV_PCT  GP_RANK  W_RANK  L_RANK  W_PCT_RANK  MIN_RANK  \
# 26      0.504         0.119        7       3       3           3         8
#
#     E_OFF_RATING_RANK  E_DEF_RATING_RANK  E_NET_RATING_RANK  E_AST_RATIO_RANK  \
# 26                  3                  5                  3                16
#
#     E_OREB_PCT_RANK  E_DREB_PCT_RANK  E_REB_PCT_RANK  E_TM_TOV_PCT_RANK  \
# 26               18                7              11                  2
#
#     E_PACE_RANK
# 26           27

# %%
import numpy as np
team_foul_prob = 0.15
np.random.binomial(1, team_foul_prob)
# Out:
# 0
